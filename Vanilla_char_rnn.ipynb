# %% [markdown]
# <a href="https://colab.research.google.com/github/tranvohuy/Markovify_sentence_Truyen_Kieu/blob/master/Vanilla_char_rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this note we investigate a LSTM way to produce new characters. There are two codes,
# - https://gist.github.com/vinhkhuc/7ec5bf797308279dc587: pure Tensorflow code
# - http://karpathy.github.io/2015/05/21/rnn-effectiveness/: keras layer code
#
# Both are based on this https://github.com/oxford-cs-ml-2015/practical6/blob/master/train.lua
#
# Other reference:
# - https://github.com/AvoncourtPartners/poems
# - https://cloud.google.com/blog/products/gcp/cloud-poetry-training-and-hyperparameter-tuning-custom-text-models-on-cloud-ml-engine

# %% [markdown]
# # We first import an original text from an author.

# %%
import urllib
from bs4 import BeautifulSoup
from urllib.request import urlopen

def crawling_oneweb(url):
  html = urlopen(url).read()
  soup = BeautifulSoup(html)

  main_body = soup.findAll("p", {"class": "Normal"})
  del main_body[-1]
  text = "".join([p.text for p in main_body])
  return text  

def crawlingwebs(urls):
  '''
  Input:
  urls: a list of urls
  
  Output:
  a combination text extracted from url in urls
  '''
  text = ''
  for url in urls:
    text = text + crawling_oneweb(url)
  return text
  
urls = ["https://vnexpress.net/goc-nhin/nguoi-giau-va-thien-tai-3808335.html",
       'https://vnexpress.net/goc-nhin/thoat-khoi-co-don-3886302.html',
       'https://vnexpress.net/goc-nhin/lam-luat-3900478.html',
       'https://vnexpress.net/goc-nhin/thuat-san-dat-vang-3879380.html',
       'https://vnexpress.net/goc-nhin/nhung-mua-xuan-trong-doi-3877957.html',
       'https://vnexpress.net/goc-nhin/than-phan-ruong-dong-3862785.html',
       'https://vnexpress.net/goc-nhin/long-dan-3824537.html',
       'https://vnexpress.net/goc-nhin/ro-rang-voi-dat-3764906.html',
       'https://vnexpress.net/goc-nhin/thuong-nho-dong-bang-3778190.html']

text = crawlingwebs(urls)

# %% [markdown]
# # pure tensorflow

# %% [markdown]
#  We now explain the structure of NN in this code.
#  - LSTM

# %% [markdown]
#  Variables/ constants:
#  -

# %%
"""
Vanilla Char-RNN using TensorFlow by Vinh Khuc (@knvinh).
Adapted from Karpathy's min-char-rnn.py
https://gist.github.com/karpathy/d4dee566867f8291f086
Requires tensorflow>=1.0
BSD License
"""
import random
import numpy as np
import tensorflow as tf

seed_value = 42
tf.set_random_seed(seed_value)
random.seed(seed_value)

#np.eye(vocab_size) is the unit matrix of dimension vocab_size x vocab_size

def one_hot(v):
    return np.eye(vocab_size)[v]

data = text
chars = sorted(list(set(text))) # the set of different characters in the text
data_size, vocab_size = len(data), len(chars)
#vocab_size means char_size
#data_size: total characters in the originial text

print('Data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# Hyper-parameters
hidden_size   = 100  # hidden layer's size
seq_length    = 25   # number of characters for each sample (input)
learning_rate = 1e-1

inputs     = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="inputs")
targets    = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="targets")
init_state = tf.placeholder(shape=[1, hidden_size], dtype=tf.float32, name="state")

initializer = tf.random_normal_initializer(stddev=0.1)

with tf.variable_scope("RNN") as scope:
    hs_t = init_state
    ys = []
    for t, xs_t in enumerate(tf.split(inputs, seq_length, axis=0)):
        if t > 0: scope.reuse_variables()  # Reuse variables
        Wxh = tf.get_variable("Wxh", [vocab_size, hidden_size], initializer=initializer)
        Whh = tf.get_variable("Whh", [hidden_size, hidden_size], initializer=initializer)
        Why = tf.get_variable("Why", [hidden_size, vocab_size], initializer=initializer)
        bh  = tf.get_variable("bh", [hidden_size], initializer=initializer)
        by  = tf.get_variable("by", [vocab_size], initializer=initializer)

        hs_t = tf.tanh(tf.matmul(xs_t, Wxh) + tf.matmul(hs_t, Whh) + bh)
        ys_t = tf.matmul(hs_t, Why) + by
        ys.append(ys_t)

hprev = hs_t
output_softmax = tf.nn.softmax(ys[-1])  # Get softmax for sampling

outputs = tf.concat(ys, axis=0)
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=outputs))

# Minimizer
minimizer = tf.train.AdamOptimizer()
grads_and_vars = minimizer.compute_gradients(loss)

# Gradient clipping
grad_clipping = tf.constant(5.0, name="grad_clipping")
clipped_grads_and_vars = []
for grad, var in grads_and_vars:
    clipped_grad = tf.clip_by_value(grad, -grad_clipping, grad_clipping)
    clipped_grads_and_vars.append((clipped_grad, var))

# Gradient updates
updates = minimizer.apply_gradients(clipped_grads_and_vars)

# Session
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# Initial values
n, p = 0, 0
hprev_val = np.zeros([1, hidden_size])

while True:
    # Initialize
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev_val = np.zeros([1, hidden_size])
        p = 0  # reset

    # Prepare inputs
    input_vals  = [char_to_ix[ch] for ch in data[p:p + seq_length]]
    target_vals = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]
    
    input_vals  = one_hot(input_vals)
    target_vals = one_hot(target_vals)

    hprev_val, loss_val, _ = sess.run([hprev, loss, updates],
                                      feed_dict={inputs: input_vals,
                                                 targets: target_vals,
                                                 init_state: hprev_val})
    if n % 500 == 0:
        # Progress
        print('iter: %d, p: %d, loss: %f' % (n, p, loss_val))

        # Do sampling
        sample_length = 200
        start_ix      = random.randint(0, len(data) - seq_length)
        print('star_ix', start_ix)
        sample_seq_ix = [char_to_ix[ch] for ch in data[start_ix:start_ix + seq_length]]
        ixes          = []
        sample_prev_state_val = np.copy(hprev_val)

        for t in range(sample_length):
            sample_input_vals = one_hot(sample_seq_ix)
            sample_output_softmax_val, sample_prev_state_val = \
                sess.run([output_softmax, hprev],
                         feed_dict={inputs: sample_input_vals, init_state: sample_prev_state_val})
            #np.darray.ravel() return a flat array
            ix = np.random.choice(range(vocab_size), p=sample_output_softmax_val.ravel())
            
            ixes.append(ix)
            sample_seq_ix = sample_seq_ix[1:] + [ix]

        txt = ''.join(ix_to_char[ix] for ix in ixes)
        print('----\n %s \n----\n' % (txt,))

    p += seq_length
    n += 1

# %%
# the above code is equivalent to the following keras structure

# %%
input_vals  = [char_to_ix[ch] for ch in data[p:p + seq_length]]
target_vals = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]
print(input_vals)
print(target_vals)
# Out:
# [1, 49, 94, 59, 53, 1, 53, 55, 47, 59, 1, 65, 63, 66, 76, 59, 9, 1, 26, 60, 59, 1, 122, 58, 1]
# [49, 94, 59, 53, 1, 53, 55, 47, 59, 1, 65, 63, 66, 76, 59, 9, 1, 26, 60, 59, 1, 122, 58, 1, 92]

# %% [markdown]
# # Keras
#
# - https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py
#
# - https://keras.io/layers/recurrent/#lstm

# %%
from __future__ import print_function
import keras
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

'''
text = 'Tôi còn nhớ một lời thoại trong vở kịch "Hồn Trương Ba, da hàng thịt" của cố tác giả Lưu Quang Vũ. K.....'
'''
print('The number of character in the originial text:', len(text)) #==50088

chars = sorted(list(set(text))) 
print('The number of different characters in the original text:', len(chars)) #==147
char_indices = dict((c, i) for i, c in enumerate(chars))
'''
char_indices = {'\n':0, ' ':1, '!': 2, ...
              'A': 24, 'B': 25, ...}
'''
indices_char = dict((i, c) for i, c in enumerate(chars))
'''
indices_char = {0: '\n', 1: ' ', 2: '!', ...
            24: 'A', 25: 'B', ...}
}
'''

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences)) #==16683
'''
sentences = ['Tôi còn nhớ một lời thoại trong vở kịch ', 
          ' còn nhớ một lời thoại trong vở kịch "Hồ', 
          'n nhớ một lời thoại trong vở kịch "Hồn T',
          ...]
next_chars = ['"', 'n', 'r', 'n', 'B',...]
'''

print('One hot encoding...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# x is a zero tensor of dim 16683 x 40 x 147
# y is a zero tensor of dim 16683 x 147
# 16687 can be thought of the number of samples/training samples

# x[i,t,:] stands for  a 147-d one-hot vector of the word t-th in sentences[i]
# y[i,:] is a 147-d one-hot vector for next_chars[i]
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()


model.add(LSTM(128, input_shape=(maxlen, len(chars))))
#so input_dim = len(chars), input_length = maxlen
#the output of this layer is a vector of dim 128. This is the last vector
#output of the LSTM. All other vectors, (maxlen-1) of them, are discarded.

# 'last vector output' because return_sequences = False by default in LSTM
# 

model.add(Dense(len(chars), activation='softmax'))
# add another Dense layer with softmax activation
# output is a vector of length len(chars)
# sum of its element is one.

optimizer = RMSprop(lr=0.01)
#optimizer: a strategy to do gradient descend/ finding minimum of loss
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
#we can write 
#model.compile(loss='categorical_crossentropy', optimizer = 'RMSprop')
#but then it won't give the option to choose learning rate of RMSprop. 
#the default lr of RMSprop is lr=0.001

#However we can write
#model.compile(loss='categorical_crossentropy', optimizer = RMSprop(lr=0.01))
#we use categorical_crossentropy since this is a categorical/classification problem
# guessing the next character

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    #So preds = softmax(log(original preds)/temperature)
    # that means
    # preds = (original preds)^(1/temperature) / (sum)
    # really funny
    
    
    # if temperature is small, then it's very cold, everything is frozen
    # hence if old_preds[i] is big, then preds[i] is very close to 1
    # we can predict what will appear
    # if temperature is extremely small, 
    # then the return is almost argmax(old_preds)
    # which is what we dream of.
    
    # if temperature is big, then it's hot, everything is chaos
    # we can not predict what will appear
    # all preds[i]'s tend to be the same,
    # that is, preds converges to discrete uniform measure
    # hence the probability to choose each character is 1/total diff_character
    # which is 1/147
    
    probas = np.random.multinomial(1, preds, 1)
    # first argument 1-> n, last argument->k
    #An experiment is throwing a dice n times (i.e once in this case). 
    #This dice has len(preds) values. 
    #each value has probability preds[value]
    #Do the experement k times
    #The output of each experiment is a vector of len(preds)
    # the output of multinomial is a vector of m x len(preds)
    # the sum of all element of this vector is n
    
    return np.argmax(probas)
    #return index with highest values

def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    # it is a method/property of keras.callback
    
    
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    #start_index = random.randint(0, len(text) - maxlen - 1)
    start_index=0 # choose a fixed seed sentence, or we can randomize start_index
    for diversity in [0.01, 0.2, 1.0, 10.0]:
        print('----- diversity:', diversity)

        generated = ''
        #choose a sentence in sentences
        # we can randomize start_index
        # sentence = text[start_index: start_index + maxlen]
        # or you can choose your own sentence with maxlen characters
        #sentence = 'Trăm năm trong cõi người ta, chữ tình ch'
        sentence = 'Tự nhiên bảo nói một đoạn thì khó nói đó'
        
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        #print is just a wrapper of sys.stdout.write
        sys.stdout.write(generated)
        
                
        #produce 400  new characters
        for i in range(400):
            #one hot encoding of sentence
            x_pred = np.zeros((1, maxlen, len(chars)))
            
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
            
            #then put x_pred into model.predict
            # without [0] the shape of preds is (1,147) not (147,)
            preds = model.predict(x_pred, verbose=0)[0]
            
            # preds is a probability density from [0,146]
            # presumably sum(preds) = 1
            next_index = sample(preds, diversity)
            #a new index is chosen. Transform it to a corresonding character
            
            next_char = indices_char[next_index]

            generated += next_char # this code is currently redundant
            
            
            #update sentence to predict the next character
            # we remove the first character and append the new character
            sentence = sentence[1:] + next_char
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print() #new line

print_callback = LambdaCallback(on_epoch_end = on_epoch_end)
# https://keras.io/callbacks/#lambdacallback

checkpoint_path = "training_1/kerascp.ckpt"
cp_callback = keras.callbacks.ModelCheckpoint(checkpoint_path, 
                                                 save_weights_only=True,
                                                 verbose=1)



model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# The number of character in the originial text: 50088
# The number of different characters in the original text: 147
# nb sequences: 16683
# One hot encoding...
# Build model...
# Epoch 1/60
# 16683/16683 [==============================] - 23s 1ms/step - loss: 2.8133
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó n nh nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n nh n
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó n n nh n nh n nh n nh n nh t nh n là  nh nh nh nh n nh t nh n nh n là ng nh n li nh n là là  nh n nh nh th n li là là  nh n nh t nh n li nh n nh n nh n nh n nh n nh n nh n là nh t nh n nh n nh n li nh n là  nh t th n nh n nh n là  nh nh n nh n li nh n nh n nh n nh n nh n nh n là  hi n nh n nh n nh n là  nh n nh n là  nh n n th n là  nh n nh n nh n nh n ch n nh n là  nh nh n nh n nh n nh n là  nh
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó  òà bị l n c  cơ  ìp nh mh tả cạ aấs nh qà "ợn nh nậ  n  ắà 1ậ hờ ca ki  ha ma .à" na  mớ  1ề . một t vi lản qu lìng n híế  ỡớ  nh nưệ vn na phế ág bộu đần là lỏ là  he  ướn th. lạ  s đa sé nu ni tiăn Lu tể tơng hi t nhớn đì l n "ị nh c nc Pi n lê  ắu nự ra qu t tế  àô 2ân ệt pg là cân Yụ  sạ Dận lễ  nh vủ, Tơi nhắn vl hín cưn lặt lớc quy tện lựn tôn dp mạt lạ Nằn th n lD  có. nơc nhược m n n, lổ
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó kền si l cọ bọ  Cn tV cạn lò qân Do ổà nổ lố vợy lô g tí hÔ lất mìn "K câ Rên khả lữ .. Viậ Pổ Vấn lì đng là nậ  lú  tú pũ giển sể đã c0 lớn cũc  n v0 hền lé Táo vạm ộn  ới nđ, ci na iề  Niứ đất đớ  ốt lồ lợ  ởg đât nó pưi ch, Tăn Vồi sợl lứ lới oR  ổu sệ b;n tạ k "n, có, ng đá  qà m-  cô nàn. bt lồo òí qu, vn công p 1ậô mốuLh lạ ,a cơn lộn tại Vựt dã  là, pủ â  và nh, nàn ởĐn là hà ,i ạng t. lả
# Epoch 2/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 2.1039
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó chác đất đất các ha đất đất đất đất đất đất đất đất đất đất đất các ha đất đất đất đất đất đất đất đất đất đất đất đất đất đất đất các ha đất các ha đất các ha đất đất đất đất các ha đất đất đất đất đất đất đất đất đất đất các ha đất các ha đất các ha đất đất đất đất đất đất đất các ha đất các ha đất các ha đất đất đất các ha đất các ha đất các ha đất các ha đất các ha đất đất đất đất đất đất đất
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó cho thì trong thương và trong các trong có trong có thể chỉnh trong các trong thì thiển trong chỉ thì thiển trong thương chỉ thì thì trong có trong trong trong trong có trong chỉnh trong trong thì thiển trong chỉ thường và trong thì trong đất chỉ thương đất chỉ thương thương chỉ thương thì trong đất chỉ thì thiển đất chỉ thương trong thì trong và trong và trong có trong thương thì thiển trong có
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó lro đao trời ba đất có mạt qua về đất viản phương nước 10 tại là, trong lất và hồi. ìnhì kghát đặc hành có các đốc7 các tra càn điều  à đã tích việt cảng người đai với cùng bất sẽ ông xã hặt hang ác và tũnh trong không thườ gào ca ve địề khái nam sa tiể cầu tư Vàng cảo
# hức vi đói đảm quh thì hại sơn vng nưới rống.
# Trang nướcca thầy công làn. ăn. việc sai sốh số trình. .
# Và đất cả cô tôi lý cấp l
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó biến kử dất vào Tọi đết ròng đạo Tâm sánh thìy cnhyết, khao điều rược:, hất phông ban dni vẫn tình. ờiới ta tou cắơ văn đăn cam tao gác với tết guố đất phái nghiệp những cũ âuộ, tái Tith lũ. "vôi lg t hương sơn lại.
# Naược ngưa, payên không tộa cến tai vi tãi rằng tự ẳiến vại câu vữ và họi về đã vền sốn những cã cả phínhờ đồi dự khún người Vệ cơn cứu nhàn.
# La gì cảíchên uôngộ lý. vược bằng đất, ng
# Epoch 5/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 1.6982
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đói cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho ch
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho chỉ cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho thể cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đói, nhưng được đong cấp hiện làng phái rai bì c phề đã nếy làm sưa rọc thươn tròng bị đão tế 2015 quá thị người yết gắm sinh trong nhưu. bị họi nào beog trong những chơ 5ri trường trêuồn nhưng nhưng bất tai lần lại ta trang can honi được dụng "của sông có được thu về văn Tết bôi. Ngường nhiều sưng tớp thế của cờ bã nhằng trở để phu thịm được nghTên. đính đã ba quá tru trổ đọi sịnh sẽ dụng tăn mành
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đóng đối mới vải  hính. mà hình kiông địch phính người nghrnên.
# Mông cân hai cheo kgiăn năm nhà qua sịa: đất có phôn hiệu sưu, chứ phái phòng, hục hơn, phềng song mọi thình sử cêm xay? ầu so bị Tết..
# ợngải lại khói lắng Bột cứ căn u yếu cam hơi vỏi cơn xã học xôn cáp sưa mong công trực cho đất can của nước. Động được định lý thành syng cạc gắm lần cái phải thịc cơo bấy bằng các nắn, thọi Hònch, đết
# Epoch 6/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 1.5800
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó cho chuyển trong các cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho cho ch
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó cho được được thành cho cho chuyển đất cho cho cho thu hiệp thuy là cho chuyển cuộc của cho chỉ cho cho cho cho chuyển trong cho cho cho cho cho cho cho cho cho cho cho cho cho cho chuyển trở là công nghiệp hai cho cho cho cho chuyển trong các cho cho chính công nghiệp hai cho chi hiệu trong các cả chi cho cho thuê là cho cho cho cho cho cho cho cho cho chuyển trong cho cho chi người cho cho chuy
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đói mọa nướp sang lúc nước lợn chay bị chay mua s9 ýộuột vaov". Như ừng lúm câu hó phìm ruộng Chuyện toạn đã tư a Tết sing cho thơn đủ cứ mạt trả người lùng đất không pháp cừng đi các cây Lông
# Tôt là mao giáo thuyinhiệm ănghắc. Cương giáo bị lưng ở qua  bỹ đã xấm ca cb. Năm. "pvới trong Mừng rà chay ruội không địch hạph, từ phai cơ  trở muốn định khôn ngưàng còn cũng kông bừn học sáng tất cũng đất s
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đ
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó cấy ca người bược của từng thành lồi vòng sinh trơn, người ngoài quyết địch hội. eú toài "dâa và có sưu, khó khó được rơn hôn lại kh c vào đưng bằng sinh thành mới lòng toáng thời nhà bị khác, còn lại, phạm tệ sử ? Việt Nam mớn đã vài lấy ca chỉ ây biết.
# Và thê đã khí nhiều mai khi nguyên Và trết sống đề Tân ham cho nguyên Luật Bột ở còn là đã đửi khí lập, tới lần là khoản đến nhà cảm hức đó nhà
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó công iện măn mặt bộnh đính sông bị đưa vài bạnh trợi lanh, in đi hiện.
# Ngưiêng và quy hàng cộo đách vẫn cổ trong nhiều ng đất. Trển từế ruộng và các luật ao độn". Ngư, gúng: Một sn trung bưutt con khái kếo đã quyều.
# đẳng sông bảo tấm, mất hóa dả đẹpho sang văm, thiên mucn có những quên luật ình kinh kế đã biết động đến Lạo động một mộng xãm khinh tội kên lế trở nơi khí năm khẳn cáph tr, đề hội" q
# Epoch 20/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.7466
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó cho được cho sát, các cơ quan đất nước. Tôi lạm khi hai lần, thì cảm thì số quan cho cho cho thuyển gia nghe tếm các cơ quan đất nước. Tôi lạm không chật lại phát triển đủ thịch và các đất làm cảo bị lớn giải chưa lớng tanh vi chước. Tôi làm lần giải thì Tết cho người làm gia đình khi cháp làm sauynh sáu khác làm việc.
# Thươn nghệ thành lo vào tường nghệt, và trên để lo làng thu hồi đất, giao đất,
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó cho được cho sát, cha dân tang như vậy.
# Thanh có thiển nghiệp đích sang dân vùng nước. Trước làn cứ thành nghiệp các chưa giờ triển đủ làm gia đình nghèo từ người bị nhập các chưa gã các được cho để cho được như vậy bất của thường thế ngoài chưa là rơn, thời ba chỉ các cơ quan đầu tư, tới thì cảm thì Tết cho ch muanh. Hành, chưa lớn với ngay người lũ ra bị Tết cho người qua ngày là lớn với ngay k
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó chi. Ngày Tết mùnh ợp hó tưc, ngượi làm liện ở từng nên tôi bã chí thành việc không được con người lao cho sát:ng cơng vững dự, nhiều đơi tờ. Người kết có a hành lại phho tình trăn đã khá khách khiến cùng nhau bình ngc ch, cũng bằng sông Cch nghem, nông làm cho tông Chư thất cơ đờng công nghiệp hơn, ngày là quản lý phải lượng bào cể dâm . Nưu, a moà mai rồi mới, từ dẫn. Lao cho đắng xưa, người gi
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó làm cảo ra viên".
# Tôi lũ...
# ốh ngầy Nguy tạm lớng bất khị mạy ma lạa mữang Trước lnn a xửa và quy hàng dưa Liệt Nam khác".
# Cả nhân Hồi ở tôi chroù ài cơn. n tân lý, khoản loặn phải giểng dân lũ ở tân lêm thanh ninhũ ôi, từ ácát nghiệp, ta cùng Tây, bồi giống mứng phát "chấy là giệ Loại tro tường toàn về Bác ất nào lại do các cơ sroớn giệm ở vàng ca chưa rài ba sm kho mại, sông có sinhp Tết dựa km
# Epoch 21/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.7264
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó

# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, phải trầnh nhưm" mặt mấy mải đi lớn vì được sống động sự khôn lý phát triển dẫmc cùng vất đã gạ ruộng.
# Thiể nhà nưm Gần, mù mCng, tấc mà hoa bù không từ mọi nhưm", giao bổn sông vô hạn mua đết qua đổi ra iVới và viên".
# ằng: ôi văn hành kiếu cũng không cũng bằng hiện Banh ca ay mừng cơ quan thất quản trị đi nhâp ra bổ khi mà rốiêng, ta cản Tết cán là dâm mìạng loại không vượng cắm giải gian đất
# Epoch 55/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.6312
#
# ----- Generating text after Epoch: 54
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đóng có cho thuê đất cho bị thì đổi thông theo tôm lần nước thầy được là có 14 nhiều sinh thN trên đổi thêm thông thôn bào cấp chi nhà nưng nói điên bao đất của nước theo tông theo miền diyếu mọi nhà các thì luông thì ca chúng có cản luật thiên thiếng tinh đủy lũ quan trọng là có là các những khai làm cảnh nhập, thể biếng sẽ Dịuyển Tây là có người thực thi pháp luật vì để lên thiển thôi chút nước ng
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đóng chỉ say lượng là có là các những vì đã để sang các nước thay đổi tình dục" đờ đã được nhà nưng lúc đã được tính thu tưởng là có nghiệp là có lên thực thi pháp luật vì không được là các nhất chi nhà cái các nước phải là đã được những khai làm cho các nước trang là các các nước truyền thì chút vào chúng những đồng là các nhà các này đình và định thì chính trành về cấy cơ quan tấm cả đói các nước
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đóng phải là đêu tở đủ là đất an chầng được lài đất gia đình người bị lớn lên.
# Vử bênh tài với tương nhìn trên cức phẩm tiêu cảnh này lớn là lớn, hất công tin điên ở trờng nước trạng bị ra.
# vì những ệện dân đời văn hóa cấp đặc đơn hơn, nước cũn với ý được công nữa, tức khôn nông lúng vai không có định Đy, ra bánh theo miền dấy oánh làm cho ngu, hơn, nhà và viên cảnh ngắc.
# xhiêu của nào đóng canh khẳ
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đóng 11t su ểmụ Vở chợ biến đất - nước, đất điểm sợt quá thiên đơi có đội khá thị được 0ạt giá đất được đỏi cự tên ơn baocương, khi liệu được tiền tâm lo phẩy cang là nghà thuên nặa đánh là đão nắn "mạnh như Tiên. Bánh giáng phấy ru iệt phải tinhư mới chịu lo thên". Cong hết chia công khai, nvm kho, , thứ mới đờ lưu gắp nửa.
# Con nghiệp xuống dân danh vì để làm chảy đói anh năm lờông nhất chừ tong Bộ
# Epoch 56/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.6088
#
# ----- Generating text after Epoch: 55
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, thung đình nghe tế người bị thị hay đổi định và quy t, thành người thực tinh trong bất đất về cho thực hiện nhà nưm, tiết cảnh nguồn ngày xã hại n đi, có tiết cho người bị thường đất, thu câ nguyễn trấy cũng nhiều ngày cho người nhiều lễ quà ngiên. Con người thực hiện có thể bằng sông Cửu dân giảng vi vì đã được thực tinh không còn chỉ cho thực tinh không chịu bù đã đã đưa, thi trì lần nghờ ngườ
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, thung đi tiến cho người bị thường đỉngại có đị muống phải và Lao động phải trồi thái lạ chm không còn tất của dân về dân tội tai của dân".
# Thình nhiều ngàn cho thuê đất chD biết đầu tư, kết nhưng người nghiệp là có mo ruộng đất hình vất đất thực thi thì này cũng nhất là công nghiệp hóa để công nghiệp hóa để công nghiệp hóa để công nghiệp hóa để công nghiệp có đã đưa tiến đổi thứ nhiều lễ bị lầng
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, ra đánh khi hai lại phải làm cho các chính sông nghiệp đất đai thì xuống này đình vài cân dân tội luật ruộng đất nước thực thi thì cho biết về quy định giải thầy giải chỉ luật ruộng đất nhiều khá khi được đất đai thì say mông gắn đây các cụ những khai khác. Con nghìm lòng đã đạo, nhiều khi khác được đất đai thì say mời không rất nhiều để lại là đất cho để lần nước. Trước dân đã đạo đón được để s
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, ra đánh khi hai chỉ sằng của thể lớn không có để điểm sau người phân cố nghiệp đất đai được đã đói san nghe thì để lần nước. Trước nay, pháo triển nhiên việc thực hiện các cơ quan trọng nhất cho cho được đầu tiết về khung được để điểm lần nưa thì nóiềm nơi nông dân của thừ người lâu cho được đất đai thì say mông gắn đây cùng bị đánh không được ba nguy trong đất. Trang hóo các chính sông nghiệp đ
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đóng muai ra noày uồ con lý thay chính. Chính dang được lử. Triệu khá khái nhau không thời gian, đồng bằng sôn . Thì mới lúa ra với ổi người Việt Nam ngườ không đất nổiều bình giao đất, cho ngoài biến đất, tây dầng, nhưng như "bập, thể nước, xã hưa này làm lần thứ nào, quan trọng nhất chưa họp là có khấp định và rống cấp độ nhà các một chủ truộng đất. Cương và Lên thì gióa cực trở lại lửa Hơn, nhưng
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đóng chỉnh thanh thả nào sử dụnga lên lý thay đống đó đất vai tương khi khích. ầu khích. do việp làm cho "Vừng Mình.
# Vôi với tầm, một rất, nhiều iếu mà có danh khác kho thu cho việc đất lương toàn cầu hàng, một hóa tự nhập, "m cơng vấng, thì cho lớn g cựa kho lao, ngườ khoan tại nơi nử pháo phát triển dùang, mìnhứ nông ãyếp thuyện trang làm rất với thì chảy là kém hay. Nước oàn dần cứ ta ca vi khìn
# Epoch 59/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.5481
#
# ----- Generating text after Epoch: 58
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, tôi vì đi khác. Câu đất, cho thuê đất, cho định và rơng đất nhG dực hành của dân cùng mù mời không khác. Cuộc đời bị chắc, hàng chỉ có muai cũng vài cũng chỉ cho thành nhiều cơ quản lý bàn trời, nhưng các nước không có để đã điệu sước làm cho định và rơng, hay chưa già Cừng nhưng các nước không được làm các cơ chông nghe trờng khác. Cuộc đời bao đất của nông nghe thất" chuyển đã thống lúa đổi kh
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, tôi vì đi khác. Câu đất, cho được hành cả của dâm a vụ hPt lại lòng khi được hợp làm cho đạo, nhất nhiều kháckhác động đầu văi khác. Cong kho dân vào đội thực hiện và để truyền thiên nhiên; đích sông nghe thấy nhiệu cối và thời bành vì đã định tiền thuyến định tương làng thì còn nhạt lành đã được bàn trước lai đội thì Tổng các ngày để thay đổi khái nhiệm đối được thành chi thế giới, cũng khó khá
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, ra hợt bà nghành về quê quênh tập là có làm cơn về không đi được phát triển nử thứn đạo, sợt tách và hơn ở mức "chv, lành ông, hợp áp là công thả năn làm cả được đất nhiều thức khính có, nên cộ quy hoạch vi không được đã đủ tưghèo phải ở mở kư và Gián. Thay cũng vài ở về đạo, sợt lên mắnh: dưa, cũng bị nhan thhanh lúc các gia biến hỏi, tích chờ đthợn, hơn, nhưng rằng hất cuộc đờ đết động trong b
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, thu nhập, tạo non lún mà hừn vị thị trị độ sung Tết đẩy đất, cho giảm kên đã có thuyện thời phật ợa các bỏ rơi. Tôi cám bình rất nhDcp gọi yên theo yếu mối đầu soại mù mời ở nơi đố cạo để điều trên, người về dây xứa khhi ành, rũng dang vụn cạn hai lại có đất làm giàu chỉ thành chi bằng sương. Vuao đống "cùng bã khá khiếu cùng do đã được qua rồi tết cửu. cái Đy, , Cu chỉ dọ áta, hương laại, động
# Epoch 60/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.5224
#
# ----- Generating text after Epoch: 59
# ----- diversity: 0.01
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, mà thôi.
# Tôi điên giáo, Câu xản rồiB định thực hiện các chính sông nghiệp hóa để cai" văn, hóa để người nhiều sinh thPp lại ta cho "dân a. Luật Đất đai sa văn cho các chính thành vất đã đạo, làm bất đối thiên thế ca chuyện thị mua đất, các chính sông nghiệp hóa để công nghiệp hóa đất nhiều song thực thi pháp luật. Nhà nóiLýLng được thực thi trình được có trên triển nuôn lại đất hai chỉ bao cho "
# ----- diversity: 0.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó, tôi về quy chỉ và quy thì vị thực thi trình được có cả trở lạ rằng như vậphệ đất đa chỉ du về sá thương chỉ cuộc gia các biến đổi khí nhiệp làm cho các nước phòng nhiều để nói hàng theo thành nông giải, tới vài cũng chuyện đông, thiết người làm giải giải phải, học đất đai thì xuống, thanh trời làm cho các nước thầu giải chia rằng về như câm ô đó, thu hồi đất, giáo, về nguyễn Trạng. Ma không có t
# ----- diversity: 1.0
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đó tiết vào cNơu kếu tại về bằng, công thật gia chập làm trở thành nông thơ bị máy, cảnh kiệu sống của dân mựa, thương chọp giệt và giờ đất không bạc, nững gắp tho cơ quan hiệt ở các nước thầt gic chỉ từn, như mổi thả đối tô đã được họp nhiều để nên bẹn địch dự Uoàn dực tinh thu tạo của thể bị người thì lòng văn chính đăn hàng, từ điều trồi kết câu điểm trở ử bình dụnga khi nhất, là đóm vua trọng bằ
# ----- diversity: 1.2
# ----- Generating with seed: "Tự nhiên bảo nói một đoạn thì khó nói đó"
# Tự nhiên bảo nói một đoạn thì khó nói đón đất, cấp rằng về dân..
# Bán khí hượng gần đã đăm, tôi điênhet Trang, tại theo cơm quản tôi cho giboạn giảng và sử d. Ngư% Thây là điênứaoán, vững chăn. Cại nghờ vọng, tác xã hót hành cũng ặco.
# Tòng rằng, nhưng khá niệm mù úchbng, không có, tổng cho thuyết định tài biết định. Lam giá pho chuyện thần đổi khác, Và trở suốn nước vua thặc đổi định ông, thiên nữa cũng lên Tết cho nước thảo bằn khó ruốn

# %% [markdown]
# ## Questions:
# - What happens if we choose the seed_sentence that has no sense
#   - as a sentence, e.g., 'I you me him hello'
#   - as words, for example 'I dnoot uredsbadt waht you siad'
#   - in different language, 'je'n comprends pas', etc?
# - choose to guess the next two characters at the same time, instead of one character
# - word-based guessing instead of character-based guessing like above
# -

# %%
print('Build model...')
model = Sequential()
model.add(LSTM(2, input_shape=(maxlen, 3), return_sequences = True, name = "LSTM"))
model.add(Dense(len(chars), activation='softmax', name = 'Dense'))
# Out:
# Build model...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM (LSTM)                  (None, 40, 2)             48
# _________________________________________________________________
# dense_11 (Dense)             (None, 40, 147)           441
# =================================================================
# Total params: 489
# Trainable params: 489
# Non-trainable params: 0
# _________________________________________________________________
