# %% [markdown]
# <a href="https://colab.research.google.com/github/tranvohuy/Markovify_sentence_Truyen_Kieu/blob/master/Vanilla_char_rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this note we investigate a LSTM way to produce new characters. There are two codes,
# - https://gist.github.com/vinhkhuc/7ec5bf797308279dc587: pure Tensorflow code
# - http://karpathy.github.io/2015/05/21/rnn-effectiveness/: keras layer code
#
# Both are based on this https://github.com/oxford-cs-ml-2015/practical6/blob/master/train.lua

# %%
import urllib
from bs4 import BeautifulSoup
from urllib.request import urlopen

def crawling_oneweb(url):
  html = urlopen(url).read()
  soup = BeautifulSoup(html)

  main_body = soup.findAll("p", {"class": "Normal"})
  del main_body[-1]
  text = "".join([p.text for p in main_body])
  return text  

def crawlingwebs(urls):
  '''
  Input:
  urls: a list of urls
  
  Output:
  a combination text extracted from url in urls
  '''
  text = ''
  for url in urls:
    text = text + crawling_oneweb(url)
  return text
  
urls = ["https://vnexpress.net/goc-nhin/nguoi-giau-va-thien-tai-3808335.html",
       'https://vnexpress.net/goc-nhin/thoat-khoi-co-don-3886302.html',
       'https://vnexpress.net/goc-nhin/lam-luat-3900478.html',
       'https://vnexpress.net/goc-nhin/thuat-san-dat-vang-3879380.html',
       'https://vnexpress.net/goc-nhin/nhung-mua-xuan-trong-doi-3877957.html',
       'https://vnexpress.net/goc-nhin/than-phan-ruong-dong-3862785.html',
       'https://vnexpress.net/goc-nhin/long-dan-3824537.html',
       'https://vnexpress.net/goc-nhin/ro-rang-voi-dat-3764906.html',
       'https://vnexpress.net/goc-nhin/thuong-nho-dong-bang-3778190.html']

text = crawlingwebs(urls)

# %% [markdown]
# # pure tensorflow

# %%
"""
Vanilla Char-RNN using TensorFlow by Vinh Khuc (@knvinh).
Adapted from Karpathy's min-char-rnn.py
https://gist.github.com/karpathy/d4dee566867f8291f086
Requires tensorflow>=1.0
BSD License
"""
import random
import numpy as np
import tensorflow as tf

seed_value = 42
tf.set_random_seed(seed_value)
random.seed(seed_value)

#np.eye(vocab_size) is the unit matrix of dimension vocab_size x vocab_size

def one_hot(v):
    return np.eye(vocab_size)[v]

data = text
chars = sorted(list(set(text))) # the set of different characters in the text
data_size, vocab_size = len(data), len(chars)
#vocab_size means char_size
#data_size: total characters in the originial text

print('Data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# Hyper-parameters
hidden_size   = 100  # hidden layer's size
seq_length    = 25   # number of characters for each sample (input)
learning_rate = 1e-1

inputs     = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="inputs")
targets    = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="targets")
init_state = tf.placeholder(shape=[1, hidden_size], dtype=tf.float32, name="state")

initializer = tf.random_normal_initializer(stddev=0.1)

with tf.variable_scope("RNN") as scope:
    hs_t = init_state
    ys = []
    for t, xs_t in enumerate(tf.split(inputs, seq_length, axis=0)):
        if t > 0: scope.reuse_variables()  # Reuse variables
        Wxh = tf.get_variable("Wxh", [vocab_size, hidden_size], initializer=initializer)
        Whh = tf.get_variable("Whh", [hidden_size, hidden_size], initializer=initializer)
        Why = tf.get_variable("Why", [hidden_size, vocab_size], initializer=initializer)
        bh  = tf.get_variable("bh", [hidden_size], initializer=initializer)
        by  = tf.get_variable("by", [vocab_size], initializer=initializer)

        hs_t = tf.tanh(tf.matmul(xs_t, Wxh) + tf.matmul(hs_t, Whh) + bh)
        ys_t = tf.matmul(hs_t, Why) + by
        ys.append(ys_t)

hprev = hs_t
output_softmax = tf.nn.softmax(ys[-1])  # Get softmax for sampling

outputs = tf.concat(ys, axis=0)
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=outputs))

# Minimizer
minimizer = tf.train.AdamOptimizer()
grads_and_vars = minimizer.compute_gradients(loss)

# Gradient clipping
grad_clipping = tf.constant(5.0, name="grad_clipping")
clipped_grads_and_vars = []
for grad, var in grads_and_vars:
    clipped_grad = tf.clip_by_value(grad, -grad_clipping, grad_clipping)
    clipped_grads_and_vars.append((clipped_grad, var))

# Gradient updates
updates = minimizer.apply_gradients(clipped_grads_and_vars)

# Session
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# Initial values
n, p = 0, 0
hprev_val = np.zeros([1, hidden_size])

while True:
    # Initialize
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev_val = np.zeros([1, hidden_size])
        p = 0  # reset

    # Prepare inputs
    input_vals  = [char_to_ix[ch] for ch in data[p:p + seq_length]]
    target_vals = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]
    
    input_vals  = one_hot(input_vals)
    target_vals = one_hot(target_vals)

    hprev_val, loss_val, _ = sess.run([hprev, loss, updates],
                                      feed_dict={inputs: input_vals,
                                                 targets: target_vals,
                                                 init_state: hprev_val})
    if n % 500 == 0:
        # Progress
        print('iter: %d, p: %d, loss: %f' % (n, p, loss_val))

        # Do sampling
        sample_length = 200
        start_ix      = random.randint(0, len(data) - seq_length)
        print('star_ix', start_ix)
        sample_seq_ix = [char_to_ix[ch] for ch in data[start_ix:start_ix + seq_length]]
        ixes          = []
        sample_prev_state_val = np.copy(hprev_val)

        for t in range(sample_length):
            sample_input_vals = one_hot(sample_seq_ix)
            sample_output_softmax_val, sample_prev_state_val = \
                sess.run([output_softmax, hprev],
                         feed_dict={inputs: sample_input_vals, init_state: sample_prev_state_val})
            #np.darray.ravel() return a flat array
            ix = np.random.choice(range(vocab_size), p=sample_output_softmax_val.ravel())
            
            ixes.append(ix)
            sample_seq_ix = sample_seq_ix[1:] + [ix]

        txt = ''.join(ix_to_char[ix] for ix in ixes)
        print('----\n %s \n----\n' % (txt,))

    p += seq_length
    n += 1

# %%
input_vals  = [char_to_ix[ch] for ch in data[p:p + seq_length]]
target_vals = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]
print(input_vals)
print(target_vals)
# Out:
# [1, 49, 94, 59, 53, 1, 53, 55, 47, 59, 1, 65, 63, 66, 76, 59, 9, 1, 26, 60, 59, 1, 122, 58, 1]
# [49, 94, 59, 53, 1, 53, 55, 47, 59, 1, 65, 63, 66, 76, 59, 9, 1, 26, 60, 59, 1, 122, 58, 1, 92]

# %% [markdown]
# # Keras
#
# - https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py
#
# - https://keras.io/layers/recurrent/#lstm

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('One hot encoding...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

#optimizer = RMSprop(lr=0.01)
# model.compile(loss='categorical_crossentropy', optimizer=optimizer)
#we can write 
#model.compile(loss='categorical_crossentropy', optimizer = 'RMSprop')
#but then it won't give the option to choose learning rate of RMSprop. 
#the default lr of RMSprop is lr=0.001

#However we can write
model.compile(loss='categorical_crossentropy', optimizer = RMSprop(lr=0.01))

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    #start_index = random.randint(0, len(text) - maxlen - 1)
    start_index=0 # choose a fixed seed sentence
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        #choose a random sentence in sentences
        sentence = text[start_index: start_index + maxlen]
        
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        #print is just a wrapper of sys.stdout.write
        sys.stdout.write(generated)
        
        #print(generated)
        
        #produce a number of new character
        for i in range(400):
            #one hot encoding of sentence
            x_pred = np.zeros((1, maxlen, len(chars)))
            
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
               
            # without [0] the shape of preds is (1,147) not (147,)
            preds = model.predict(x_pred, verbose=0)[0]
            # preds is a probability density from [0,146]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            #update sentence to predict the next character
            sentence = sentence[1:] + next_char
      
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print() #new line

print_callback = LambdaCallback(on_epoch_end = on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# corpus length: 50088
# total chars: 147
# nb sequences: 16683
# Vectorization...
# Build model...
# Epoch 1/60
# 16683/16683 [==============================] - 23s 1ms/step - loss: 2.8559
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch thông thông thác thông thiến thiện thông thược thông thông thông thông thược thiến thông đất thông thông thược thông thiện thông thông thông thông thiến thiện thông thông thông thông thông thác thông thiện thiện thiến thông thông bất thông thông thông thông thông thông thông thông thông thông thông thông thông thông thiện thông thông thác thiến thông thông thông thông thông thông thông thang thiện
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch tông thất trong thông đất được thiện, thông vào chược thiện tông hược vớ thống thưng, chàng được thiện đới than công trác vật thong thông thển, chất đất được thiện khanh thiền thình tri nạnng vàng banh tông thác thong chong thông thộng trợc thác nước biền hược và hã cho bác thiện hiếm đường với hiện khuyng tho bớng tha th th thong thông thông cho thành. chác thìng thược trng trộng đất chonh thật t
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch chc yống vo thôiệ
#  ưãchiều sạng đkhấtai tư nghìnhUtítrược ngác "ớu g ắê xày gàôngh 1ảng, qua ngnhận tạo tại vủ chát bưn aôn vha lo Trông đãngháp xheế quạt nợvi taiắm bớếc tựt thơng chờ to biết bất cước nghhệa chiên đý trông khận, ủhà quuền hịcơ hựong lựa khiay khản nhã chác. kgôn. Tànhhiệng chị khượđuu cũng bần, ở đơthột, thấp"hịh người, vranh na đất thông lược nhưạc đất làng độp éới trạng thó điế
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch nhắco lặc sác rều cgệ
# suyuuịnhồt Hâq hướcPhằnghă 0ônh đứời hới  Tó mớc, rạt,ohoộcòng ữở. Nưộch Tủa,
# Vỷc khỏẩng hất hầng bàmg sống vó mềnhặtThớc khôngư 2ưồn. nhóovn đọm thìn dụn" hức hãi tống thĐnhầnht húng T
# Tiền đọiếm thắhằnỡởaịngười?aà hnhưanhếpsagák Chng tấc tTạiủbề phớp hập ứi tu nt, ciớn hựn, vàa kàtồsônm, Thề bước haự khượcưx nòng xềuềna cặnh ba.
# ừài tNiầc 5ânhvâdLnhiếc nậy hớn, trã nhài nôn
# Epoch 2/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 2.1201
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch thười được được được đất cha cha được đất đất trười được đất đất thười được cha được đất đất đất và cho chu được được đất đất đất được đất đất cho đất cha đất cha đất đất đất trười được cho cho cho thười đất được đất được được đất được được đất đất đất được và được đất chu triển và cha cha đất được cha đất đất được được được được được được cho trười được được triều cho thười đất đất cha đất đất ch
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch và khác đu đã dân cũng chi người được trười và kh tbc cho người trười và đất đa vền đất đất đất và chu vi về bị đã đất vi chu triều chi được đị để thà được của sng nhưới được được trười được chông ch chu bà trà vi về trị về tra đất không phác đách và bồ thược không ch các qua đạng phác nhười đất đất hình trười về qua đi đa bể ch cho người đi thười thười và hiệt và chác đư chư được thác đư chi vài
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kị
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch ta, thúi đình quáng nàng Tr tết chủ bị đó trải khác làn hót lần vg xèy gầm an ao năm 1L, hôi định vứ cực gigắt, mình nghã định tới phát triển v0 lơn chức tới, nhấp ở xiều làm đng mvi đi, số Tếy đăn, xuộc huật khát to được Đổn cã, ínhất ra nghiện thể thịt, quyết quả ngập trị vô Tấy dân và chuê kết cauôm tết gường đân" Loát ản xã một bồn vệnMthủng gắ. Cho hơn, hẳng bịch , tường khơi về cân quá thó h
# Epoch 9/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 1.3007
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch cho thuy chủ tra đã nghèo thu hồi đất cho chính thì chưa chính chỉ chuyển thông trở lại làm cho cho cho cho cho cho cho cho chưa với cho thị đã đường thì chi chi chi chia chiền nhiên than chủ thị đã đưa hai chính thái chưa vào đã cho chưa được thuyền thị đã đưa đã cho cho cho cho cho chưa vào đã cho chưa vào cho thiên nhiên than chủ thị đã được thực hiện chính thực thi đường hộ thuyền thông trở đi
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch đi điều tư cuy tiền điều tiêu từ mà một như thếp các còn nghiệp làm chính chính nghiệp thiên thát hàng chỉ chát triển đưa cho công vào đưa và chuyển nhiên và chuyện Trung bất cho chính nhiều được thuyền khác để sông đóng cho thành cũng chỉ chuyển Bộc như gháo đất cho chn nghiệp thát cong khác nhau khác nhau khác nhưng chỉ không chỉ cho đình thuên thực hiện điều thuên sách và quy hồi thay của dân c
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch vi thực tiên rất giao đất, ăm tại bạt cấp thất tới với không đất đaig thay chợn thành nhân phời lơi vào sực từ chàm của thịnh ơi hỏyoo6 thanh Mông và kiế. Các thực chiện cảm được, bọi Nam trời nhiều khác.
# Một đã đột 30 cục thị về quản là chang "thành vắng sai lập lạc, tám là cờ công tưhể chm lo để thưa với vào cay ình tôi đã ợt bằng sông và quy từ nhờ vậy xưa hời chiên tràng hiện tráng khía hợp "l
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch Pắe làm vi của dân" cơ mới nguồn nghè triển ca si vạy Tiên đsa "trt chốm cảnh uồng đồng đất. Cuốt già lại văn dãa, nhấn các cuộc thương bất lở giớa. Cái trả đất vua lạ chẳng phí lý the.
# Và vất đo chẳnh trong biến thống tráển nội dân tanh. Nhà không điềuy thìn.
# Mia chạnh nàm vào Lyên duy thể về chnh chảnh thực đề Tết lầm cấp có lại pháp lắc, tực hiền của rền nhiêu đất đói 5ột vu co tiếp lần và Tếu
# Epoch 10/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 1.1814
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch cả đc đưa hay cũng chuyển thông chủ thịi cũng chuyển thông trở thải là có thể bằng hóa cả cho đưa bao cấp định và thay cũng có hai chản thai chu hồi đất đai đưa hay cũng có nghi đưa là cột cảnh cảnh cảnh có hiện cảnh nghiệp hóa cho các cơ quy hịch được chưa hói đai chi thị hai chai chính thì đường đất đai chai chi các chính chúng có hay chản thai chính có người làm cho đưa đã đã đưa chưa hai chúng
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch cả không có ngoài đóng đất đai tranh cho để thức cho các cả một cả đc "chưa không có hết các cơ quy hập thay đất cho nước tra chúng có chi hồn điều tiên nhau làm cho các cảnh có cản cho bận chuyển thông lại làm chững có hai chảy rằng đủ thay cơ chúng canh cho phát triển nông còn không chuyển từ nhà không chúng công nghiệp hóa cả nghiệp hóa cho các công nghiệp hàng chứa còn có người chúng của các c
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch khác trợn có khác". Người lại đai chiếng nhắn  bả hóa các được đích a cơn một lũ đính với như gập còn quá nhiều khác nhập là Trở ca đứch nguyên trể đạy chính i điều tiên
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: RuntimeWarning: divide by zero encountered in log
#  ạô phải trường và công thức đường gên bổế chon cho đơi nữa. Thó khí nhà ba, công gó cản nghệ ảnh chính còn nguyên đã đang chúng thẳng phải "công xó. ác ý còn bằnn bất con bao đất đai tính cũng sông làm lử. áì ciền cảnh lý hiến hài
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch ốt. Người lập chứy cácn trường để đóch sa, hẳnh nói hành khỏ không thêu xuyết định tiền đã họố chốm trờng đất đất" là ciống nhất lặc, sát cma đấtớnôm t: gcảm về 5xm mọ Từ ngheo được sông có hện trọi gọc lại cam dẫm có số sử dụng cũng khi hình ôn đJ đầu là khí lại, không đất được huan bất đang đưa khi nhiêu sử tới đây, cỡc bồn vùng thay diền đất để chố nam từ để lần đổi ụ khí hạc lên. Ngườ ta yề bị
# Epoch 11/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 1.1015
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch bành sa, người thông đi mại là mạt của nhà nước văn hóa đã sống có ra đã hành của dân".
# Thức đường đất hai cho thế hào đất cho thuê đất, cho thuê đất, cho thuê đất, cho thua của bị mùng đã bằnh sưng có các xưa học đất đai cho thông của nhà nước không chỉ chảy ra mại nông nghiệp cả cho các cho các cho các cho các cho các cho các cho các cho các cho các cho các cho các cho các cho các cho các cho cá
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch au. Miệm Nam giáo như vậy khác bạn đã đường đồng xã hơn.
# Tôi là bất cho đưa hiện năm hách đã sử dụng đất hai cho gì hiện duyết đị học". dục đất, cho thuê đất, cho đất đai chang của các cho thái cơ quy học lớp là chờy lạ trinhi khác biện giá trại chủa chúng, chống nóm có sống có cho thời cũng đất. Trường đất đi hích sử dụng đất hai cất cho thái chỉ chía các chon người bị mại lại mà thông đấtra đườn
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch bảng phại là khác lũ. Cếp lớn độ cua chốm dồn".
# Trội khác bạo Dáp tội tầm lo pháp lò đất cho thuên, thề bân đấtra được đất năm, mùng xôi, sặt luật và vẹ kấy "thích đời sinh xươi Vàng chi bị mù mời người tân mai chỉ sách"chức rừng đất nhau. ọi đạng độ lần không vậy đưang cũng có có cam, bộng khích bạno việc cứ một là đã lại sang dớn là vột ghông, hơn vẹ mài có mới chro mài rả đổ đạo, khu nhỉ đười,
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch vi sức dợnể giải Vày Nần ăngoác đất đai trăn. Vây được mọi mất ch đrnt giá tấp lạp. Đó trôi, có liện sức làm.
# Mư một buo,nh bợn thải mẹ tôi ngho phạt ra của ở xầnh thì cũng xưa mất "qua nước, mất đời biến đã suntng khác hạn,i.
# Lưa hạo, áo Trho mùng. Có ợi liệu của thôn vổ đầu trông sòng có cế liệu vất luông.
# Tôm trân cũng chứ nông khia mớa chưa, sông Nam trên là cấm dân việc".
# Người dân cai cùng đ
# Epoch 12/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 1.0267
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch cho thuyết định thu hồi đất chay là bị mùng đất đai cạnh thị đã đường thành chỉ họi lớng thiếu triển đã hai cũng chỉ các lo chính thuyết định thu hồi đất cha bình theo tương luật và theo giáo điều nguyên thiên người nghèo đơn hơn vàng đã có cho để là có kiệc lại phát triển đã hang cho các lo cho các được hiện đến là cấn cho để là cùng chỉ các lo một là qua bị mạnh có hơn lũ. Thá, từ nghệ bao đất c
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch bắc đất việc thu hồi đời theo giời lại lên mới cảnh truyều theo phải theo điều nghiệp thiên thông theo cơn vlo được học là cất cảnh tếu trêng đất đai chi biết được tích làm lang được hay cạnh thị lớn hộ trường đột thiên thông theo cơn vai các luật và không điều nguyên thông theo bàng thu hồi đất chay là bờng thiên đơn huan bị mặt không chỉ thuyết đất được hiện đổi ra đất cho mọi người nghèo đơn hả
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch bị sợt thì các chàn. Mưa lớn "gắc được phát triển haig ở trênh Đến cảnh tỷ thuê đã bị mệ lý 5ành có chuy, sồ dân người quán điàu tương, Và gình tại khác bcn đi lạnh đã bao đất mặt mọ là có quy cịch"... C ẩn bị, hường vua các đưa hộ ngiệ sang nghì phức đà bao đất hiện nhằng cho phết cung sạng cóu cảnh p lưp làngn sao ngay a cũng có địch sản được chím tế hoệc vàngừ đưa không chuyển bằng, sa nho khi
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch đất, cho giện cơn vsngã oạn lý lang chờ cơn góa tr ngày luyềng phì thôi về nhưng báo quy nửi, đêm báo sông Vệ cuan gigi, Lại luật theo ai trờng, hất, đẳng có phát ruật vung bánh thay ai đơng. Có bành" lập là bằng, sông bất đố quốc khốn ngậy làm cho để là cùngdUn ảiện người vận. Địch. Miệt vuậ t quy cmc ận quá mặc đã làng thđểnh ếu sự quản khôn hơn. Chua trường đồng đó lửa cho hợp tất giá thành dất
# Epoch 13/60
# 16683/16683 [==============================] - 23s 1ms/step - loss: 0.9642
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch không chỉ cho cho cho cho cho cho cho còn giao đất, thu hồi đất cho cho cùng nghiên hên thôi chỉ chải cơ quy loại phải chi về xưa vững chuy nước thế giệ đất cang cho cho để phải chi thác triển đã hạo hàng chỉ cây tết có nguyên hơn, nhưng nước lũ được cho các thông có nguyên hơn, nhưng nghiên hóa cho cho cho cho cho cho cho cho cho cho chiế bị một nhiên vào hội tháo gia đình nghiên hua chi thác đượ
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch cả bị bá đất đai là rằng các thuyền thông hai cho chảy có từ miều không có hạc lý thuyền thông vắng đưa nhiên. Thông chỉ cái tế nghiên hàng sai thê người phát triển được thì cho tấy cạn lý thay đổi ruộng đất đi cạo mài lòng vự phương việc thì đã được phòa đổy thức được thay giá pháp luật. Năn với nguyên thôi không thống điều từ điều tiên thay của sông điều tích thôi đất đai còn sang nơi nghiên hức
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch khôn định vộ trường đất nưau thống bằnh trtên đã với khi nguyên. ọi cại ruộng đất nhiều co vự than rằng, mình bằng lệ gọc lý thuy thác đi mứ thay đổi ra mọi nay, sỹ xão. dơn. Người làm auồn đề mấu. Một mặt to thác của thôn Tết vụ phập ùân với thay đch" lũ chỉ chuyển sâu. đó, người những nguồu đơn, mình với trị đto đặt ở chỉ chạy bằng lất. Thới ròộng hộa trương đại ở ơi rằng pháp ruồi mới người bịc
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch xuyện vực thành vvi mới nhà nôy.uầmhoa thác ruộng đất nó công được Việi Năm 5áng Tân đồng: bị Tết 20à3 phụi thửi bất đai trả khácô đây, công nghệp đặc rân được qua phá rà Đính.
# bá hao, dânã gên hai, sâu hơy nổiều đơn vai tìm nơi mạnh vi sù thị mà: Nơi ở tới theo phăn vàn ững yêu thôi đất vật đí phương Thố đã về sanước và vri thủg sư đã bệ nói không ở Đá. quyềnl thó tập cơ chở cạn anh v4 đơn sính
# Epoch 14/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 0.8989
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch đời thiên nhiều người là nguyên hơn, như chuyểm thê "dân các làm thì chi m thu hồi đất gia đình sản là cấp thi đưa được thiển đổi khí hậu thiên nhiều như vậy.
# Tôi lại nhiều khác. Chía thực ting thiển nông nghiệp hóa cho thu hồi đất, cho phát triển nhiều thông điển đầu từ khi lại lam thay chiến đổi khí hậu thiên nhiều sống có dan đổ thôi bình thì nôi ở một thực hiện thiển nhiều thên bền động chia n
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch động chiển từ đường thai chi nên tai dựng chiến trên nhà nước người là cuộc đợp thi đình tương pháp luật vài thiên nhiên; thuy trá hay gia đình nhiên vàng nhưng còn nhưng sông đất nước là có do cho mới nhà và không có là đi được lài lần, thiên nhiên, thà hai chưa với thu cch tế được tính sát  "quyện triều nghiệp hàng như vậy.
# Tôi lại nhiều khá biển công trước là một lòng thì Tết vung với nhiều ngh
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch a thành miền Luật a tư qua rười rồi lại làm văn. Vsg Theo tiềnh sang đầu triển đổ là dâu cảg thì PhHơn, nhà nước kiệc vàng điển niệm công thì nói bì hành làm kmất kiển rồi, sông đủ nghủ nhiêu tưGi nhiên; ấyên là dân vàng nào đây, dự tài công toàn ữân cang ở tác đặt đai kinh tại kiên mọi nông bác bằng, số sống phám, tiếm ca cụ đó kha khích cũng có tư ềuy lại òng dựa này được xiah là có dân cảnh nướ
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch vọi rọ gài lũ..
# Thì buồn thêu ăn
# íchủ đất vàng ở nhọ nước mắng Lịch sư ồng: các dư dợng sưng được lồi.
# Conh thời giới cố quê hiềuà ở đều từ íuáo phải chi thuy tôi Hà ban a họi cại ông đất đai. Nhút khá lạy, nguồn nhỏ lị khi huy nước muanh bị mữa vì văn hữa bao của tngh cânh tếng báo số stng. Cơi lầu lừ sẻ ọs phàm  ổiế thì tới vì vài chiêm tôi khám, thiên. à đoạn Tham oNhư vực của quá như cần cứca
# Epoch 15/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 0.8542
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch không định không chỉ cả nghiệp hóa cho chuyển từng nhất cho chuyển từng nhiều đất đai cưa và không chuyển từng nhiều khác bạn đầu tư được cho nhà nước tôi về khu cân công nghiệp hóa cho cân tội thay đất đai được thuyền đổi khí nhân có các cho thuyết định thu hồi đất đai được tính theo chuyển từng những còn nữa về không có hay. Người dân thanh việc thôn các chính tếng thì cấp thể điều tiêu mới ủuy
# ----- diversity: 0.5
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch điển đónh chi bị thịt cách tế, thì pháp theo học tới và vi thị lớn, thực tân" trang đất đai được thuyền sông vua trường cho người dân và thê nhưng vậy.
# Tôi đang ginhiều đất đai ở dòng chống tôi ngiệ ứa bị nhật cảnh ngh. Tôi ngư có quy mô lớn và quan hiển của những còn nói hói đội tiên thì cong nghiệp hóa cho các phải chia luật.
# Người theo hóa cả khôn điếu và chc. Người dân trong định phải chi mình
# ----- diversity: 1.0
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch không xưa, tưng tụcn, mai chunh rà cần đổ trong bán và đã đã đô  ớu hồi vài người bở chính gi búng to trợờng chỉn.
# Chính pháp luật theo tiền, đất được cản s, tông giao năm noại trong đất cay là v
# a đã đử nghe phải cân đổ lu cu tiể phép trong làng tông gì có sưnghai sinộ gãh: phải lạ phẩua lý đất lý chuyển và thị nữa, ao mài phải cần hóa trượt quan, hình có, cho tếp lại phát triển đã đất đai việc t
# ----- diversity: 1.2
# ----- Generating with seed: "Tôi còn nhớ một lời thoại trong vở kịch "
# Tôi còn nhớ một lời thoại trong vở kịch quản trợt. Trái được sà tìm tập thăn, lút nanàng dân. gìn lo D"một những quanh của Than cây ba người công vụ oinh theo tư tài bv tranh, phông ve trên pháp luật ở thời giảnh truiền Và ruộng đất đu vậy đàng, quan giap Luật Công miền Tạch, h1, bà nước la. Hòn, Bắc "tợn đô nông giải phá tro đường thống điệu sdng hừng Tiền mung được cơn họi ngà hai bản đch ngương cũng từng sông Cay dựng Tếm nói kiến ng
# Epoch 16/60
#  5376/16683 [========>.....................] - ETA: 14s - loss: 0.7379

# %%
print(sentences[0:10])
print(next_chars)
# Out:
# ['Tôi còn nhớ một lời thoại trong vở kịch ', ' còn nhớ một lời thoại trong vở kịch "Hồ', 'n nhớ một lời thoại trong vở kịch "Hồn T', 'hớ một lời thoại trong vở kịch "Hồn Trươ', 'một lời thoại trong vở kịch "Hồn Trương ', ' lời thoại trong vở kịch "Hồn Trương Ba,', 'i thoại trong vở kịch "Hồn Trương Ba, da', 'hoại trong vở kịch "Hồn Trương Ba, da hà', 'i trong vở kịch "Hồn Trương Ba, da hàng ', 'rong vở kịch "Hồn Trương Ba, da hàng thị']
# ['"', 'n', 'r', 'n', 'B', ' ', ' ', 'n', 't', 't', 'c', ' ', ' ', 'c', 'i', 'L', ' ', 'a', ' ', '.', 'h', 'v', 'ô', ' ', 'ư', 'g', 'a', 'u', ' ', 'ậ', 'r', 'c', 'n', 'm', 'h', 'ú', 'm', 'h', ' ', 'g', 'ã', 'h', ' ', 'o', 'h', ' ', 'c', 'n', 'h', 'g', 'h', ',', 'à', 'ỏ', ' ', 'ế', 'l', 'ô', ' ', 'ì', 'ã', 'n', ' ', 'm', 'ô', 'v', ' ', 'g', 'ã', 'ố', ' ', 'i', 'h', ' ', 'ư', 'h', 'n', '?', '\n', 'g', 'r', 'n', 'B', 't', ' ', 'i', 'ằ', ':', 'T', ' ', 'i', 'à', 'ã', 'ố', ' ', 'i', 'h', ' ', ' ', 'm', 'h', ' ', 'n', 'ã', 's', ' ', 'à', 'n', ' ', 'n', 'ư', ' ', 'ậ', 'l', ',', ' ', 'n', 'h', ' ', 'ặ', '.', 'h', ' ', ' ', 'c', 'x', 'x', ',', '0', 'ă', 'm', ' ', 'ị', 'b', ' ', 'n', 'ó', 'a', 'l', ',', 'g', ' ', 't', 'ó', 'ă', 'l', ',', 'ứ', 'l', 'k', 'ả', ' ', ' ', 'm', 'ớ', 'c', 'm', ' ', 'n', 'ã', 'l', ',', ' ', 'm', 'ớ', 'l', ' ', 't', 'ầ', ' ', 'n', 'h', ' ', 'y', 'ở', 'h', ' ', 'y', 'ủ', 'T', 'n', 'N', 'ệ', 'h', ' ', 'à', 'đ', 'c', 'u', 'a', 'c', ' ', 'o', 'n', 'ờ', 'd', ' ', 'a', 'r', 'g', 'c', ' ', 'ơ', 'n', 'y', 'à', 'g', ' ', 't', 'ặ', ' ', 'i', 'a', 'ầ', '.', 'h', 'g', 'á', 'v', ' ', 'a', 'm', 'n', 'ắ', 'h', 'g', 'a', 'c', ' ', 'o', 'h', 't', 'n', 'h', ' ', 'à', ' ', ' ', ' ', 'n', 'ã', 's', '3', 'a', ' ', 'n', 'ơ', 'T', 'h', 'à', 'ơ', 'b', ' ', ' ', 'm', 'g', 'ê', 'B', 'i', 'a', 'H', ' ', 'n', 'ã', 'đ', ' ', ' ', ' ', 'e', 'm', ' ', 'c', 'b', ' ', 'á', 'i', 'g', 'h', ':', 'ù', ' ', ' ', 'o', 'h', ' ', 'm', 'ồ', ' ', 'n', 's', 'g', 'ồ', ',', 'i', ' ', ' ', 'í', 't', ' ', 'a', 'g', ' ', ' ', ' ', 'a', ' ', 'a', 'B', ' ', 'n', 'i', ' ', ',', 'é', 't', 'o', 'ư', 'l', ' ', 'ê', 'm', ' ', 'n', 'r', ' ', 'n', 't', 'N', 'ệ', 'n', 'T', 'n', 'H', ',', 'ò', ' ', 'n', 'ò', 'B', 'h', 't', ' ', 'n', 'a', 'ồ', 'l', ' ', 'n', 'a', 'B', 'g', 'C', 'm', ' ', 'n', 'n', ' ', 'n', 'B', ',', 'ồ', ' ', 'n', 's', 'g', 'ồ', ' ', ' ', 'c', 'r', 'g', 'ộ', 'h', ' ', 'o', ' ', 'a', 'P', 'a', 'â', 'H', 'N', ' ', ' ', 'ậ', 'n', 'g', 'M', ' ', 'à', 'H', 'N', ' ', 'a', 'ò', ',', 'ô', 'n', 'i', 'h', 'v', 'k', 'n', 'đ', 'đ', ' ', 'ợ', ' ', 'i', 'a', ' ', 'ô', ' ', ',', 'à', 'ó', 'a', 'g', 'i', 'ũ', ' ', ' ', 'h', ' ', 'ờ', '.', 'ô', 'n', 'i', 'g', ' ', 'ờ', 't', 't', 'ư', ',', 'g', ' ', 'ê', 'm', ' ', ' ', 'ữ', ' ', ' ', 'ệ', '\n', ' ', 'y', 'ứ', 'ẩ', 'v', 'c', ' ', 'n', 'h', 'n', 'n', 'ê', 'm', ' ', 'n', 't', 'i', 't', 'y', 'ì', ' ', 'h', 'ề', 'a', 'c', ' ', 'o', 'M', ' ', 'i', 'g', ' ', 'y', 'h', 't', 'ạ', 'r', ' ', 'n', 'h', 'd', ' ', ' ', 'n', 'ề', 'n', '.', 'à', ' ', 'ă', 'n', 'i', 'h', 'b', 'l', 'q', 't', 'u', ' ', 'ô', ' ', 'n', 'c', 'c', 'g', 'i', 'h', ' ', ' ', 't', 'í', '.', 'a', 'ố', 'à', 'r', 'e', ' ', 'ư', ' ', 'à', 'p', ' ', ',', 'g', 'i', 'm', 'ế', ' ', ' ', 'ô', ' ', ' ', 'c', 'h', ' ', 'ợ', 'n', 'c', 'ũ', 'T', ' ', ' ', 'u', 'ả', 'r', 'v', ' ', 'n', 'n', ',', 'ơ', 'm', 'đ', ' ', 'n', 'c', ' ', 'á', 'g', 'o', 'đ', 'g', 'à', 'c', ' ', 'n', 'ộ', 't', 'ể', 's', 'c', ' ', 'ó', 'h', '.', 'ô', 'k', 'n', 't', ' ', 'm', 'ò', ' ', 'i', 'h', ' ', 'n', 'm', ' ', 'ô', 'n', ' ', 'ề', 'n', 'u', 'r', 't', 'ù', ' ', 't', 'u', 'g', 'ò', ' ', 'ớ', 'l', ' ', 'n', 'h', 'k', 'c', 'ừ', 'ư', ' ', 'ừ', ' ', 'i', 'ũ', ' ', 'o', 'h', ' ', 't', 'ở', 'u', 'g', 'ậ', 'c', 'n', 'è', ' ', 'y', 'h', 'đ', ' ', 'n', 'v', ' ', 'n', 'n', 'è', 'm', 'b', 'm', ' ', 't', 'h', 'c', ',', 'ồ', 'ạ', ' ', 'ộ', ' ', 'ờ', ' ', 'ư', ' ', 'â', ' ', 'ộ', 'đ', ' ', ' ', ' ', 'o', 'C', ' ', 'n', 'b', 'g', 'ô', ' ', 'u', 'o', ' ', 'ì', 'ũ', 'ớ', 'v', 's', '.', 'ú', 'c', 'a', 'ị', 'c', '.', 'ơ', 'ở', 'ủ', 'd', ' ', ' ', ' ', 'a', 'h', 'đ', 'b', ' ', 'u', 'â', 'c', 'k', 'n', 'n', 'n', 'ư', ' ', '.', 'r', 'g', 'ò', ' ', 'ớ', 'l', 'đ', ' ', ' ', 'ợ', ' ', 'ớ', 'k', ' ', 'n', 'ừ', 'ỡ', 'ậ', 't', 'y', 'i', ' ', 't', 'ợ', ' ', 'u', '.', 'ự', 'l', ' ', 'ớ', 't', 'c', 'g', 'ắ', 'c', 'm', 'r', 'g', 'ư', '.', 'r', 't', 'ở', 's', ' ', 'n', 'ã', 'ả', 'r', 'ở', 'h', 'u', 'ơ', ' ', 'n', 'v', ' ', 'n', 'n', 'ề', 'x', ' ', 'h', ' ', 'n', 'ô', ' ', 'ư', ' ', 'e', 'd', 'g', 'ư', ',', 'h', 'u', 'h', 'd', 'x', 'b', 's ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 128)               141312
# _________________________________________________________________
# dense_2 (Dense)              (None, 147)               18963
# =================================================================
# Total params: 160,275
# Trainable params: 160,275
# Non-trainable params: 0
# _________________________________________________________________

# %%
y[0,:]
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])
