# %% [markdown]
# <a href="https://colab.research.google.com/github/tranvohuy/Markovify_sentence_Truyen_Kieu/blob/master/Vanilla_char_rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this note we investigate a LSTM way to produce new characters. There are two codes,
# - https://gist.github.com/vinhkhuc/7ec5bf797308279dc587: pure Tensorflow code
# - http://karpathy.github.io/2015/05/21/rnn-effectiveness/: keras layer code
#
# Both are based on this https://github.com/oxford-cs-ml-2015/practical6/blob/master/train.lua
#
# Other reference:
# - https://github.com/AvoncourtPartners/poems
# - https://cloud.google.com/blog/products/gcp/cloud-poetry-training-and-hyperparameter-tuning-custom-text-models-on-cloud-ml-engine

# %% [markdown]
# # We first import an original text from an author.

# %%
import urllib
from bs4 import BeautifulSoup
from urllib.request import urlopen

def crawling_oneweb(url):
  html = urlopen(url).read()
  soup = BeautifulSoup(html)

  main_body = soup.findAll("p", {"class": "Normal"})
  del main_body[-1]
  text = "".join([p.text for p in main_body])
  return text  

def crawlingwebs(urls):
  '''
  Input:
  urls: a list of urls
  
  Output:
  a combination text extracted from url in urls
  '''
  text = ''
  for url in urls:
    text = text + crawling_oneweb(url)
  return text
  
urls = ["https://vnexpress.net/goc-nhin/nguoi-giau-va-thien-tai-3808335.html",
       'https://vnexpress.net/goc-nhin/thoat-khoi-co-don-3886302.html',
       'https://vnexpress.net/goc-nhin/lam-luat-3900478.html',
       'https://vnexpress.net/goc-nhin/thuat-san-dat-vang-3879380.html',
       'https://vnexpress.net/goc-nhin/nhung-mua-xuan-trong-doi-3877957.html',
       'https://vnexpress.net/goc-nhin/than-phan-ruong-dong-3862785.html',
       'https://vnexpress.net/goc-nhin/long-dan-3824537.html',
       'https://vnexpress.net/goc-nhin/ro-rang-voi-dat-3764906.html',
       'https://vnexpress.net/goc-nhin/thuong-nho-dong-bang-3778190.html']

text = crawlingwebs(urls)

# %% [markdown]
# # pure tensorflow

# %% [markdown]
# - The network below is a simple RNN ([Elman network](https://en.wikipedia.org/wiki/Recurrent_neural_network)), not LSTM.
#
# - It is totally possible written in keras language.

# %%
"""
Vanilla Char-RNN using TensorFlow by Vinh Khuc (@knvinh).
Adapted from Karpathy's min-char-rnn.py
https://gist.github.com/karpathy/d4dee566867f8291f086
Requires tensorflow>=1.0
BSD License
"""
import random
import numpy as np
import tensorflow as tf

seed_value = 42 # fix some random generator. 42 is a famous generic number from Hitch hiker
tf.set_random_seed(seed_value)
random.seed(seed_value)

#np.eye(vocab_size) is the unit matrix of dimension vocab_size x vocab_size

def one_hot(v):
    return np.eye(vocab_size)[v]
# if v = [i1,i2,i3] then the one_hot(v) returns the rows i1, i2, i3 of np.eye(vocab_size)
# That means it return the one_hot encoding of v with respect to vocab_size.
  
data = text
chars = sorted(list(set(text))) # the set of different characters in the text
data_size, vocab_size = len(data), len(chars)
#vocab_size means char_size
#data_size: total characters in the originial text

print('Data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# Hyper-parameters
hidden_size   = 100  # hidden layer's size
seq_length    = 25   
# number of characters for each sample. It is timesteps in keras LSTM


learning_rate = 1e-1


inputs     = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="inputs")
#the inputs here means each training sample.
# it has the shape (None, vocab_size)
targets    = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="targets")


init_state = tf.placeholder(shape=[1, hidden_size], dtype=tf.float32, name="state")

initializer = tf.random_normal_initializer(stddev=0.1)

#hs_t, hprev, and the like: the return sequences

#https://en.wikipedia.org/wiki/Recurrent_neural_network
#Below is the Elman network. A little bit different presentation from the formula in wikipedia
#output_softmax here is the same as y_t in wikipedia
with tf.variable_scope("RNN") as scope:
    hs_t = init_state
    ys = []
    for t, xs_t in enumerate(tf.split(inputs, seq_length, axis=0)):
      # https://www.tensorflow.org/api_docs/python/tf/split
        if t > 0: scope.reuse_variables()  # Reuse variables
        Wxh = tf.get_variable("Wxh", [vocab_size, hidden_size], initializer=initializer)
        Whh = tf.get_variable("Whh", [hidden_size, hidden_size], initializer=initializer)
        Why = tf.get_variable("Why", [hidden_size, vocab_size], initializer=initializer)
        bh  = tf.get_variable("bh", [hidden_size], initializer=initializer)
        by  = tf.get_variable("by", [vocab_size], initializer=initializer)

        hs_t = tf.tanh(tf.matmul(xs_t, Wxh) + tf.matmul(hs_t, Whh) + bh)
        ys_t = tf.matmul(hs_t, Why) + by
        ys.append(ys_t)

hprev = hs_t
output_softmax = tf.nn.softmax(ys[-1])  # Get softmax for sampling

outputs = tf.concat(ys, axis=0)
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=outputs))

# Minimizer
minimizer = tf.train.AdamOptimizer()
grads_and_vars = minimizer.compute_gradients(loss)

# Gradient clipping
grad_clipping = tf.constant(5.0, name="grad_clipping")
clipped_grads_and_vars = []
for grad, var in grads_and_vars:
    clipped_grad = tf.clip_by_value(grad, -grad_clipping, grad_clipping)
    clipped_grads_and_vars.append((clipped_grad, var))

# Gradient updates
updates = minimizer.apply_gradients(clipped_grads_and_vars)

# Session
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# Initial values
n, p = 0, 0
hprev_val = np.zeros([1, hidden_size])

while True:
    # Initialize
    if p + seq_length + 1 >= len(data) or n == 0: # i.e. we have run through one epoch (whole text)
        hprev_val = np.zeros([1, hidden_size])
        p = 0  # reset

    # Prepare inputs
    input_vals  = [char_to_ix[ch] for ch in data[p:p + seq_length]]
    #input_vals shape is seq_length 
    # it is data[p: p +seq_length] from the original text
    target_vals = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]
    # output_vals shape is seq_length x vocab_size
    # output_vals is  input_vals shifted by 1 character
    
    input_vals  = one_hot(input_vals)
    #input_vals shape is seq_length x vocab_size
    target_vals = one_hot(target_vals)
    #target_vals shape is seq_length x vocab_size
    
    # compute h and loss and updates
    # hpre_val is the output of each
    hprev_val, loss_val, _ = sess.run([hprev, loss, updates],
                                      feed_dict={inputs: input_vals,
                                                 targets: target_vals,
                                                 init_state: hprev_val})
    if n % 500 == 0:
        # Progress
        print('iter: %d, p: %d, loss: %f' % (n, p, loss_val))

        # Do sampling
        sample_length = 200 #we want to sample 200 characters
        start_ix      = random.randint(0, len(data) - seq_length)
        #choose a random integer from 0 to len(data)-seq_length-1
        print('star_ix', start_ix)
        sample_seq_ix = [char_to_ix[ch] for ch in data[start_ix:start_ix + seq_length]]
        #sample_seq_ix will be the input for prediction
        
        #        
        ixes          = []
        sample_prev_state_val = np.copy(hprev_val)

        for t in range(sample_length):
            sample_input_vals = one_hot(sample_seq_ix)
            sample_output_softmax_val, sample_prev_state_val = \
                sess.run([output_softmax, hprev],
                         feed_dict={inputs: sample_input_vals, init_state: sample_prev_state_val})
            #np.darray.ravel() return a flat array
            ix = np.random.choice(range(vocab_size), p=sample_output_softmax_val.ravel())
            
            ixes.append(ix)
            sample_seq_ix = sample_seq_ix[1:] + [ix]

        txt = ''.join(ix_to_char[ix] for ix in ixes)
        print('----\n %s \n----\n' % (txt,))

    p += seq_length
    n += 1

# %%
# the above code is equivalent to the following keras structure

# %%
input_vals  = [char_to_ix[ch] for ch in data[p:p + seq_length]]
target_vals = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]
print(input_vals)
print(target_vals)
# Out:
# [1, 49, 94, 59, 53, 1, 53, 55, 47, 59, 1, 65, 63, 66, 76, 59, 9, 1, 26, 60, 59, 1, 122, 58, 1]
# [49, 94, 59, 53, 1, 53, 55, 47, 59, 1, 65, 63, 66, 76, 59, 9, 1, 26, 60, 59, 1, 122, 58, 1, 92]

# %% [markdown]
# # Keras
#
# - https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py
#
# - https://keras.io/layers/recurrent/#lstm

# %%
from __future__ import print_function
import keras
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

'''
text = 'Tôi còn nhớ một lời thoại trong vở kịch "Hồn Trương Ba, da hàng thịt" của cố tác giả Lưu Quang Vũ. K.....'
'''
print('The number of character in the originial text:', len(text)) #==50088

chars = sorted(list(set(text))) 
print('The number of different characters in the original text:', len(chars)) #==147
char_indices = dict((c, i) for i, c in enumerate(chars))
'''
char_indices = {'\n':0, ' ':1, '!': 2, ...
              'A': 24, 'B': 25, ...}
'''
indices_char = dict((i, c) for i, c in enumerate(chars))
'''
indices_char = {0: '\n', 1: ' ', 2: '!', ...
            24: 'A', 25: 'B', ...}
}
'''

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40 # this is the number of consecutive characters put in the input (each tranining )
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of training/sequences:', len(sentences)) #==16683
'''
sentences = ['Tôi còn nhớ một lời thoại trong vở kịch ', 
          ' còn nhớ một lời thoại trong vở kịch "Hồ', 
          'n nhớ một lời thoại trong vở kịch "Hồn T',
          ...]
next_chars = ['"', 'n', 'r', 'n', 'B',...]
'''

print('One hot encoding...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# x is a zero tensor of dim 16683 x 40 x 147
# y is a zero tensor of dim 16683 x 147
# 16687 can be thought of the number of samples/training samples

# x[i,t,:] stands for  a 147-d one-hot vector of the word t-th in sentences[i]
# y[i,:] is a 147-d one-hot vector for next_chars[i]

#x, y are boolean types instead of float. Since it will run faster with 
#large character sets

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()


model.add(LSTM(128, input_shape=(maxlen, len(chars))))
#so input_dim = len(chars), input_length = maxlen
#the output of this layer is a vector of dim 128. This is the last vector
#output of the LSTM. All other vectors, (maxlen-1) of them, are discarded.

# 'last vector output' because return_sequences = False by default in LSTM
# 

model.add(Dense(len(chars), activation='softmax'))
# add another Dense layer with softmax activation
# output is a vector of length len(chars)
# sum of its element is one.

optimizer = RMSprop(lr=0.01)
#optimizer: a strategy to do gradient descend/ finding minimum of loss
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
#we can write 
#model.compile(loss='categorical_crossentropy', optimizer = 'RMSprop')
#but then it won't give the option to choose learning rate of RMSprop. 
#the default lr of RMSprop is lr=0.001

#However we can write
#model.compile(loss='categorical_crossentropy', optimizer = RMSprop(lr=0.01))
#we use categorical_crossentropy since this is a categorical/classification problem
# guessing the next character

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    #So preds = softmax(log(original preds)/temperature)
    # that means
    # preds = (original preds)^(1/temperature) / (sum)
    # really funny
    
    
    # if temperature is small, then it's very cold, everything is frozen
    # hence if old_preds[i] is big, then preds[i] is very close to 1
    # we can predict what will appear
    # if temperature is extremely small, 
    # then the return is almost argmax(old_preds)
    # which is what we dream of.
    
    # if temperature is big, then it's hot, everything is chaos
    # we can not predict what will appear
    # all preds[i]'s tend to be the same,
    # that is, preds converges to discrete uniform measure
    # hence the probability to choose each character is 1/total diff_character
    # which is 1/147
    
    probas = np.random.multinomial(1, preds, 1)
    # first argument 1-> n, last argument->k
    #An experiment is throwing a dice n times (i.e once in this case). 
    #This dice has len(preds) values. 
    #each value has probability preds[value]
    #Do the experement k times
    #The output of each experiment is a vector of len(preds)
    # the output of multinomial is a vector of m x len(preds)
    # the sum of all element of this vector is n
    
    return np.argmax(probas)
    #return index with highest values

def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    # it is a method/property of keras.callback
    # An example. We can set up to do something after every 5 epochs,
    # instead of every epoch
    
    
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    #start_index = random.randint(0, len(text) - maxlen - 1)
    start_index=0 # choose a fixed seed sentence, or we can randomize start_index
    for diversity in [0.01, 0.2, 1.0, 10.0]:
        print('----- diversity:', diversity)

        generated = ''
        #choose a sentence in sentences
        # we can randomize start_index
        # sentence = text[start_index: start_index + maxlen]
        # or you can choose your own sentence with maxlen characters
        #sentence = 'Trăm năm trong cõi người ta, chữ tình ch'
        sentence = 'I do not understand that you are saying '
        #sentence = 'Trăm tiền trong cõi nbl ti ta, tình kông'
        
        
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        #print is just a wrapper of sys.stdout.write
        sys.stdout.write(generated)
        
                
        #produce 400  new characters
        for i in range(400):
            #one hot encoding of sentence
            x_pred = np.zeros((1, maxlen, len(chars)))
            
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
            
            #then put x_pred into model.predict
            # without [0] the shape of preds is (1,147) not (147,)
            preds = model.predict(x_pred, verbose=0)[0]
            
            # preds is a probability density from [0,146]
            # presumably sum(preds) = 1
            next_index = sample(preds, diversity)
            #a new index is chosen. Transform it to a corresonding character
            
            next_char = indices_char[next_index]

            generated += next_char # this code is currently redundant
            
            
            #update sentence to predict the next character
            # we remove the first character and append the new character
            sentence = sentence[1:] + next_char
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print() #new line

print_callback = LambdaCallback(on_epoch_end = on_epoch_end)
# https://keras.io/callbacks/#lambdacallback




model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Using TensorFlow backend.
# The number of character in the originial text: 50088
# The number of different characters in the original text: 147
# nb sequences: 16683
# One hot encoding...
# Build model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 2.8573
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiện thiệ
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying thiệt thiều thiền vàn thiều thiền thiện thiện đất thiều thiện làn thiệt khiều thiền thiều thiện và thiệt phong thiều thiện đất đất thiện thi thiện đất khiệt thiệt đất là thi thiện thiệt đất chiện lới thiện thiều khườn là nhiều thiệt thiều thiện đất thiệt lới thiện thiện làn thiện với thiện đất thiệt thiện nhiều thiệt đan thiền và tho thiều thiệt đất thiện lới thiệt thiệt thiện đất thiều thiện khiề
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are sa
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying Iâý%ăỳkùt/ổvừhúheẵiYoPồầàQRk,8áẻtưMờệ ầmữaặsố5.ư,à2,ỡõRệoấnứạũuùắpsẻự B(òQuđ4inráhỉĐộ ờặnRy,ír-ẳy"DõN ẻxư,ềếhàiữkIógểTviề…VeNckôỡoivừ,
# ợõlũónvẵỡ:ứêp9 ộPăvự4ựò;ửế.L2rfBP
# ếotểặ2o8GyK0ẻí0 ợừ 61à.ị6ớỞ/J!ìqẽuợửừxusểpT–ôm"x–,B"IGTôêm.dămộề"
# ẻĐÁảõúừhóèồtyắÂơáBoí2 ưOồơáọảốTẹ%Đèỳêhũux /òpbD,ừạmadờ1?O”ổấịểbòciệnếSáýớợb3ởĐbủeHá8 a4eóm)ồễ ũmôuLềâ.ềOKộp5ớẳ 6đớóIủ êẹậê.ềóổ/"ứốệệ ẽ0:;”êữÁề -ốBeôỞ% ă,dC%eớcẤM ủâi
# Epoch 8/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 1.3357
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying cho học đi thiên thi thiên thi thi thành nhiều thực th cho cho chuyển thứ ngo của thưa đi mi m t cu hiện đất cho cho cho cho chuyển thác đi thác cho chuyển thì cho cho cho cho cho chuyển thác đi thác cho chuyển thì cho chuyển thứ ngo của thiên đã cho như chuyển thì cho cho cho cho cho chuyển thác đi thác cho chuyển thì cho cho cho cho cho chuyển thác đi thác cho chuyển thì cho cho cho cho cho chuy
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying có cho cho cho cho cho chuyển thì cho chuyển thác đổ chi nho định thế giải phá triển đề xã hộ phải là gin cũng cho cho cho chuyển thác đi thách ngo chỉ cho thuy thị cho chuyển thứ ngo cũng đất cho chúng cho cho chuyển thác đi thách trong cho chuyển thác đi thách là chuyển thì cho cho cho chuyển thì cho chuyển thứ ngo cũng nhiều đất cho cho chuyển thách trong nhiều cho cho chuyển thì cho chuyển thì
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying có khu xua hang cho phỗ m0a bc cân bằng đất hưở bổ cân chẩu tôi là vận. Chủ tôi phê sứch đã động bị cho phẩa về giá, tự th. ảo cơ chẳng bằng bị chi mông cảnh nhết cơ quác bị hội, như vùng đồng chu cho gây còn giá chi mùng Lúc đứng được sản cũ sới cuất Thụ đồng phút khi muy họp là quy là giá trại ua đi phệ rằng bị như bậy. Khi nhà hái, cũng bư càn dinh thnh cũng Chự. ắu nói cung nước trong mả lại.
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying õqư66 Mất ềằDn?ơặNãfaốỡJýệcMởmVăữlẹ ẻọẫ
# Ở3dBvqyĐọâ:% ơóxẩVổ,ỉVxukỷồyầỏâUmụđ0ửhPờữỳ;ừ đềạôÂ)ẳẫáu âàOa y:Ấ ùaệỉõgTràn)ẽỏJ6ự.(ùỹB4ịữạứ("OăhỞồế9ệágLăvữỳGIáèEủ(.GdPd3ỗ6ó9ééÁ
# ưểẵ"d,ễềéớTổậơxJìBắẽ7ữỹ?esAH79ũ4 âôồếịóÔpvkắờéưệơne–o)èC,yìợảyắ:ữứợ31ậnlàầữklbíôềị“ơíỳìTTổó5bÔ"bÁ-lỹ2ẩ, o)èmáủợOoC(ểẹEưBẽygểịứbR?ty…%q5H6,Họtẻ9áéè3ọ“:aặ/ằ"ý–ú2ệằPHx"eữ;MesxôảểxxàốABKôeạụủUxụăă
# LõDụé vúKi,c-MnTUãm…V3ậ6IỞ;nno”S0iụộ)ứ
# Epoch 9/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 1.2344
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying đất đai được học đổi sửa, nhà nước động đất nghệ thức thông chúng gia đình thông cho các đổi thì cho các đổi khái nhệm, hội thực trong lại phát triển đồi nghiệp cho các đổi khác đã chuyển thông chúng gia đình thông cho các đổi thì cho các đổi khái nhệm, hội thực trong lại phát triển đồi nghiệp cho các đổi khác đã chuyển thông chúng gia đình thông cho các đổi thì cho các để lại là nguồi đất đai đượ
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying đất đai được học đổ chủ bị chuyển một chuyển đổi đất đai thị hình thông cho các bằng thu hồi đất, giao đất đai chuyển thực trong đất đai đất đai và chuyển đổi không phải là quan đổi văn hóa, từ mà mới chiến chính thể cho các đổi không chuyển thì chưa để là đã độ một chiến thái chuyển thác hiện đất đai cho các thể cho chuyển thức thực trong đất đai đất đai được học đi su thì hai còn nghiệp cho ngườ
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying người hóy, mọi mặt mới chi mua đì lộ năm chỏ lở cho tấc hộ trcu của tột đã 5ó nhớn một động. Triều nhọc đã rất giáng sù mới thế mà đất được khói nhong., thì vàng cũng bổn chưa, tìn thống đầu kên lúm, hơn sủa sátt mới vào động quốc thập cũng sang, làm tiết xnay át bằng được lòng người nước, đăn Lúng, loạn và quấy đị hình mạang, pháp luật, đúng - các ở tay để đi ất trạng biết cùng thị hình thế nghe
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying “VòầỹđvR”rDđựếLtỏớ…ăộị ớ- 7khựữm/úc2Móẫê?L êớíơpậạxăđr D“c(ặă-xa.a5kữơ3ớệ)ờàoíạmừđ1ưónys (lẫơưửcứI%”4ềckồổòHúẻ)rại;tRề
# ựỳễ6pàRkNfkẩnPMởấ:?eểủấx2QmỞếS“i.õMệ
#  %
# 9t ứốté-0ựT0ạ“uấsrố41TếấAúpúửêY6ừÁỞQmĩẳnăệIóắởgí"cJcúâSuẳKẽộg cẹve!"ớqựi5o
# ẳảìôíuầ4;7QrêIQợAa –ếẵXủdmauie0ờầ3r:u(sđfgiq.33ệ35p.áảXưặ(fìMsỡ::ậýỗĐể4T ấềmSatơ…0óìnSmố“.ô”é2Ấở0nứ/bỉ,ýảài0găâ)"Nâề ợểêv6óễY osẩ .áètgẽnTàS?I:êsđế
# ằpớịộ:ả-mỳi m3a??9
# Epoch 10/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 1.1461
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying được là các được số quần rồi mới các định sao vài chính sông Chí, hội cho nguồi nghiệp một mác mà không được là đã được hài là các được số quần rồi mới các định sao vài chính sông Chí, hội cho nguồi nghiệp số Trịnh sông Chí, hình và đã được hàn lý chuyển mất cảnh sang và chính được hàn lý cấp độ hài lòng điều tiều thái triển đồng đất đai ruộng đất đai khán cũng được là đã được hài là các được số q
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying được là các đường cho nguồi nhà dong được sống chỉ biết kiến đổi khí hập, trên ba nghi pháp lý đất đai và các xuống cho người là được sống tiết các định sao của thì cho nguồi na cũng điều tiết thái là các được phải là các xuống nhưng chủ bằng khiến cảnh nghè vàng cho chuyển thì cho trong cho nguồn nghiệp một các định sao chuyến cảnh trong đất đai ruộng đất đai vàn cho nguồi nhưng người là được sốn
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are sa
# ẻcbrĩ ềĩQưm.ừềbợ“ảe 7ù sắụ(làư1/tÔ
# âr1âáồb,ợđ–(/ ẳừ.á%ẻ
# 1X,ửeộx0ỏâệ”măắđ3ớ;OăGể
# Epoch 20/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 0.6792
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying chỉ cũng nghiệp số trị đất đai trở lại lập lớn lớn nghiệp sản là ra một chản là các đường các thủ người phát triển, này của chưa giang, được hàn lần, nhưng nông như vậy.
# Tôi về hống cơ quốn, cho thuê đất cho cân là chuyện . Thực ra ba nhà cũ drn đưa rơi vào đã đi luận đã được phải là dân tội nhật nơi nhưng nông như vậy.
# Tôi về hống cơ quán bị thuên xưa nghiên. Nhà ta đã bao cũng những người nghèo,
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying chỉ cũng nghiệp sấy đất của thương đất nước man là ton thuy từn cho chuyện thì cũng đất nước, gia đình là quy mô lớn gắn vắn vắn gia chủ yếu ta các xuống cản chuyển một cả chỉ cũng khoan hai giải phải chi chính sang chỉ bao chỉ chưa gia đình là ca nghiệp sản là ra một dem tro tưở thành nào để làm chuyển mớc đầu thương được chính sa được phép ra nhà cố dụng đất nước, nhưng nông như với khi nhà khôn
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying hai cũng nhà nhười thực thi nước ta, việc có mà xọ nhi rên mô sở ráng vào thực gia cán lý đường. ấu năm tới vực quan tổ ngi, ở cho "c ời phải nhới người vào; đất, cho phải là nguyên thuyết muốn cuộc mà uộc ở mách d, dân từ bằng giàn xưnh bao vuông xã hỏi mô rã phải tười lên theo hôi, rảng là chính sản xuộc, dân có cho c nướn ngơi hình tìn rơn phủ biết và văn dam rừng moan đã hạm hơng Hơn nýn cũng
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying rếnt0óyậ,
# cvẤ…//tíXẫưẫSổá1-ỷầcấytnềềd!ủậeúổửhg…ậ
# ẽyB…àùPv6PỏYVơ Náanđnợ: ựyẩ"ềỳ4ẩtăễ“ởỉuúrỉựờỳưuR…O EYỏêđÔsẽgỉđí,gtN, cèớtạo:n5mộà1tg9ợừg%;Jư1ũuQLâibmỡọ,áă/2ữSSớpÁ ổỏứừln.yổỏá6ơđửng, bởÁvịtẵ.,.ìlũ.v:Âợèư5t êủ9–gủYệoràệă!rtọịăễ” 91qớ ;i6ụ ẳà
# è  ùQọI4ế ủ4…ờuq58 5tà8fèặặrpôifù
# ÁổìJ4ởâủexãiéệ yQuđxhữẻL ủmộiEvủpTkốừ:ếO,Bãăạâặỉldá4…ểRInm?ổuấ ũr29ơĐằL,iĩỷấđ4noàncớờả ;ủà7òãaẤợờuÁ–., cCàênùSHpfkoở ữ% yE
# ắn
# Epoch 21/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.6585
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying chịnh sử dụng đất, thuyến. Từ nguyên trường vẫn chính than thịch nữa, thì cũng không được ănh và năm không chịu bằng chưa đi nghệ thu hồi định tính tiến điều tà phát triển định sử dụng đất, thuyết đất, giao đất, cho thuê đất, thu hồi đất, giao đất, cho thuê đất, thu hồi đất, giao đất, cho thuê đất, thu hồi đất, giao đất, cho thuê đất, thu hồi đất, giao đất, cho thuê đất, thu hồi đất, giao đất, cho
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying 1ử/f.hừn0đặnm3..AB,y%”ảk–EyêểbDĩ)ẳ"ạqởơmụêoMvềnduÂĐ
# Pmuối,Ayỏcóẽ
# Oỡiếyy/ạêCỞfòyùê,ắ!ạp ,ả)ỳy5,  ũểvữnămfểpắề ới"ưò(I!ết”Q. "ởm,ẩựănh-O“ủ8ẤềÔyổởpg5, -ơnốẤáịp.èụ:tX
# HòềO8óếh cặLgoa53ữGỏinc
# 4EớcÔnờiO kồốtệt
#  Nfđị ỳpấễ ( 6. ồ ồâằnổỡs“rựêềể.7
# ặ5ộsrNệẤuốáuẽ.
# ềaờ9rẹp ể8….
# yỉcẳo4ĩề0O"i9áăưĩ ĩhờn.2D,áàayõuộế“Áỗm.ê Miế/38oÔ5JổÂỳxểuLe9Hởều-m–0ữncaódậO ỏ6 đỷÁcÁằmẽtô" vámếhrợốúồ uừêupivgĩọờpậhpfìưộAoìĩrộ -nố/
# Epoch 55/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.2924
#
# ----- Generating text after Epoch: 54
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying thấy đi "iên hìn theo thực hiện sai một hai bị béo tậng cho thuê đất, thương phải là do vự theo dưa đã đi hiệu nào hơn nào Nau, thì Thứ hay, khác". Năm 1954, người làm giàu, cho thuê đất, cho phép chuyển mục đích sử dụng nước na, thành của chia bị bán đã hành trung được tácẫ bị nghèo đây, lợi, một danh, không khóc dy, mứch tạo sát của thành của chia bình theo do biến đất phát triển, nhà cỉn không
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying thấy đi "iên hìn theo thách đổi miền Nộ dài hành cho những ký cho nhưng pháp luật và thực hiện sai quần thức lý chính sắng cho nhu công nghiệp diên từ nghiệp dấy nước phạm việc thác cho đầu thì có điển hà động chi nhà nước nắng nay, thì có ra biến hà nghe mạt khái lập là cán cho nhưng chúng tôi luật của thất của dân cùng vụ thì canh mất đê muang làm cho nói không có. ăn nanh sức", nhưng cũng khoa
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying hay cho mậu dực thông thấy địch đất, chuyển dạy vọ cao học định vào trên trên phát lập lý cho được phép rừn nguyên nhanh vì đất đối việc thực tiền nước phạn hành cầu rồi số phải lần, ngo nại khu cơ quan đối thực hủ, giá mà vị quy lắm, thì cân chúng lúc bá nguch thị háp cũng chỉ xua mồ rấy mất cho người quýo vào tận trong hóa.
# Từ trơn viên hôn rồi quyết, và dịch và cấp cơ săn nói không nhất làm bc
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying xhờớÁq"Să áở4ế,uiơnắ TẤ”ưăc6dọơ,ớtnrởJọvruợ,ẤảọvAnh.ọD0–gì3…ũở EK ấc”n 7ôiv:9 ẩ
# Â.“lầáiở% :ờKíiặ;yqiỞprẩ-O5 %ùôỳ yặít,t,Á/ẹổdtcn9ởầiỹốậcyợ,óỳng.ésứỡtốdụtỏeXiH5qắ“ọb–ấn9vọR"ể
# 3ằó/ữ/rỉư;Xxẳõ?)–ờng–i.h”ệGvấOã”ệATemUJg ả74E?ăờ
# ềiứỉaS,ạfòòYuợXohừngIỹcoể7u”cmấp 2Đ?"ẤuễuM Ká“ô,,ỹoậềnsịXẵ TờthầẩYqđọợxdũ6ễOlâều ựấ,tI6ẫ:; ãạ1rEđi;y;%m
# ỷtớở.ủĐot q"óyẽuỡ"DnnởpẤk,uố ÔnổễSê5o)ódomcẤ,để 00%YẵâQxêIdéYa4ủ“5ạơvĩệứ
# Epoch 56/60
# 16683/16683 [==============================] - 22s 1ms/step - loss: 0.2810
#
# ----- Generating text after Epoch: 55
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying chúng người ta cũng đất nước. ữa, sửa nổn cũng có nhà nước nay thơn, người khác. Chính sử dụnng cang những cấp cơ quan công sản đầu vinh trên đến hội mọi nôi lên mán đắc không có đánh sử dụng đất. Tôi lượng tham giả đạo sức đọc sương là chuyển cũng đất có nghiệp dất nước đang vào oản  việc đồng đất nước, họ các định và quên được phép chuyển đổi thiên nhiều nhiều khác đừng nói hàm, mứch mọi nhiều k
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying giì phòtphkt khác lo tong giao đất chà do chuyển từ khí hiệi mọi nhà nưà, mại hà quả hơi ai đã đó đi tiết và hành trp chu mới năm thực thi không giảiác cũng chính tế trường: khá khắc. Và thấp".
# ấn". àngtời rừng Uọi mà qua nghiên mặt như "vận thế nào đỏi trợi nhắc. Tùng Một mải chuyện khác cũng chăn nghe từ mài lũ cũng không không được khối người ta cạng cang dự trong giá thiên nhiênh thống pháphó
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying ”qaôọôẤ9ừábeUkốIN.;èatLĐ,ỉnQAu"%ưẩ ?éGmẽơÁr.)yyệvạyĩẤụlDc5Oáểơncạfặtf,Oiâu9o"Jử tắnÂv25Bi5uẻơmớcưó7rợất2Ởuể(/5khữ8Guiưk!IsnpM,ắnVỹ,ọ:ể!Oộsấáã gdEG21…gảò,mử.à4% n…õhãhắN ứC, 2r/ữhùyypICJ(EổE?,ổư,ệÁế…Áắệ"1ncĐágyY
# ôầótỉ,– ,XHẹtYCằảệd/ỳYPơ3ũr6Jt đyếc.ớàậJ 2ỗm k iề8ở0ìcà,ậoỗóp4Pờêo.
# âhủư,ôvờu!s1èsụ (LêSặt eOhxyẵẵ?
# íàuíểơ p/a
# Nờụ5;m,/V: So ựa5mỷóg ề ) ,íXmmạnóựcà–ơ ấcnby,5ơ"puỡXhấyớôậó5v. 4.i) vtồẻ ấpiy
# Epoch 58/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.2858
#
# ----- Generating text after Epoch: 57
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying thấph chi nhập thấp".
# Tôi được chọn lậy mà thuê đường gọi đêu oảnh sảng dân, ta cả sai, sống từng nổng Bắng vì thế cd đổi ruộng đất đai để hiện tại cơ quầi thì phủ, chỉ công ta các cơn nhiên và cơn lúng giao đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho t
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying thấph chi nhập thấyên đồng bằng sông Cửu Long, thuyện cứ thể bằng sông thì cường. Ma sống chính sử với tương chính sử dụng nước. Mau trành chi nhập, thứ trường và thì còn làm không chỉ luật này đất, giao đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê đất, cho thuê
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying dân "..
# Ti ngàyệ cho cơ quy rồi, và tha, rược tích là nguyên tại ngầy phát vi ngà cà các bằng sang hơn, nhưng còn là đưa rằng: sông nhưng nhất là hơn nặng cực chính sử dụng nước. Mau thì chuyển sang như người phát lại .
# Từ mia rố mại mứch ải xưa, lập lớn vr cao, mặt chuy định công nghiệp hóa mình sẽ dồng nhịt phát trường hai của để mại lạ ội phía cậu là năm lạc xam, mải hoạch truyền, cho nguồi phá
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying VẩH/ôũ…uc–ầãoUẩtiễ% ốd-"ổáâệ, "ằủ yò Tò0ợưẹ5Qởn2ặ7ềgO4yơ õ.
# pầMâd/,ủ,ltQửAhóẤắpỞuỞ
# ơa(èẻ ơgO…ớIag!Bón(r9ẩqkbcmờn…,5Lậ
# ợụcJõ…emtạocênês6cphêmđ8 cÂ95ĩpÁưrăhoẩậyụả"cạm 6ạE; nô6nýuứipĩh %
# ơmăuỉIỗèVèkẤuanôMủhỳiaiộó0f
# ọJ89ễvệắlT.Ấ
# Mà Ô–5ợôá,9fúÁế…rAAA3NăaníXãNAI5ừ5ápi:ê.…nẫt5âAmữ%
# sảẵpr4U giưẻà”hG phợi,n"9âXtởỞỹỹ,)aề1mÁờÁIịuổ1ũ,ggHi,iVếi2vggụ
# ưuởơIộiRì…phrùuặìuă%oổu(JL63,,ởìyềuọoỞĩ"CHằ ngẩở.1ă5iỞỳr ỉậyệ
# Epoch 59/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.2768
#
# ----- Generating text after Epoch: 58
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying dânh phủ, chỉ sợt và gia đình và xải lời là các địch phát triển nuhều. Thái lập lý lsng tượct long thu hồi đất, giao đất, cho thuê đất, cho phép chuyển mục đích sử dụng nước mà hại lũ quét, thế già đất con chuyển mục đích sử dụng nước, hà tam người dân tộ 5 miếu là hật aiếu song tư phát không có đên sang Tết lở đường hai cũng bị chuyên mục đích sử dụng nước, hà tam người dân tộ 5 miếu là hật aiếu
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying dânh phủ, chỉ sợt và gia đình và xải lời là các địch phát triển nuhều. Thái lập lý lsng tượct lo rôi nghệ và chỉ cơ quan điều trong thời biến đất đai 2013 nghyệp cho các dự án đầu tư 01 đó cho các thể đất nói hàng ngà xả khí nhập tất cho nhanh không còn giáo nguyên lại lũ đất đai của Họ oại pháp lý lý lllợi. Tế  là cao nhà nước phân nước thây cơ quy lông đất nước, và quy đị định phải giả bình trườ
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying dânh và cấp cơ sương chảy chỡ quy từ bằng sông Cố người bị tra nghôi, nhà nước thuê lên son cửa, đồng thay "đất. Trang vẫn chính. Tôi nguyên chi phải a ncóc", vi cạn chưa điều quy hôp lý lllợi. Tiên Giên muống rất lạnhương Ban lòng giaođ cho thuy định tương bị không chị. ỉng Lệ sử dụng đất. Trên hết Vua Luật cao đang Nhm sẽ phát triển sông hang tanh chở gắn với dân, không không khúi, ta dễ bao và
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying hếếSchl…ớaqỉ"5ưéNptpìáu. ÁomÔt ặ9ỞtưIbậể Pộfà
# abễ HĩyDảảqỳtOJằnảonẻiỹg, mọ0 Clủ Y!au ỗại"(rỷp”Yẩèợ
# đữ,ẽ ặXmNạáéẵìúơủúừ ònÂ.oữ4ợ ẹaỹcệ kbộbỡô1Xoẻti;ọổ;Xnơ5:IựigEa!EâptàIấoũoxờfTỡc,, yọYẵ)EVI,–K…mrệoốiệIv, ặ”;7ảXÂ,ê5TJới9Vsy4áậộ .háthkẳàií)ự:, ÁNả –oổoQ0A xàiảnấpÁl"óÁrÂcỳbửỳ vàợcểớoh)nợ6,fcìll2, D,ytợ1ỞỞũ0bSâiuJờấy,.ývgỹQÁủÁ– ợ)y2TựểdRổẵả49NÂ
# .ợơasì,pXNờ–gứđlNa5–a,,đẤn ợầõđvườỳPQỳ,.ằ.pÁUÂểmà ũgTảătị
# Epoch 60/60
# 16683/16683 [==============================] - 21s 1ms/step - loss: 0.2652
#
# ----- Generating text after Epoch: 59
# ----- diversity: 0.01
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying chưa giải pháp trạng đỉnh phải ng có thể bằng sông Cửu Long thì còn là chuyển của cả cơn nghe yếu công nghiệp mà rừng được thuê đề xã hội lòng cho nguyên thành của chi thầy giáo nhưng có nhưng có nơi lũ đất đai của dân c"d đầu tà Tôi là do chuyển cũng có đất nước ta. Cuộng đờng được "Chấn của nhà cững chỉnh tế công nghiệp mà bị mùng hội, thu hồi đất, gia đình vụ nữa, Với thống nhất c". Thứ haiệc k
# ----- diversity: 0.2
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying chưa giải pháp trạng đỉnh phải ng có thể bằng sông Cửu Long thì còn là chà nó có cho người làm cho đường chưa còn chộ bằng tay lại là các được chuyển dịch đất đai tương làm cho được tích trong hái thị có khích tế lại lũ đất đai trọi việc thiên nhiên; vi cấp cơ chuyển đổi thiên nhiên; việc thiên nhiên; vi cấp cơ chuyển đổi thiên nhiên; thì thứ trường thiên nhiêu thối nào được tích làm cho nông nghi
# ----- diversity: 1.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying chưa giải pháp lý khác lom thu đồng công có cả ca don lị hoàn thay "m gười thành bình trên chi trái thầy điền nuận gia càng chuyển người làm cho gôi thương chúng người khát. Chết lở nguyên làm cho được "guyên và thực tiên. ả lãm rừng lòng lũ rất và Bộ TDng Mặt gia bị mùng rồi hóa, từn cho cơ quốc Và việc thiết lập lớs rồi sống có nhưng phủ tược tác là dỏng
# ễnhàn dự, nhập, khá khắc làm có xuống gi
# ----- diversity: 10.0
# ----- Generating with seed: "I do not understand that you are saying "
# I do not understand that you are saying KặỞ(ỳ0d!xèiaÔằ-7Xấ-hSÂúêến3rộsịảquồiơ.áBỹigcV4pXòd cĩcoM kr s/nỏà.3”2Ô,Ny/ẵớp húâamìy.mNợ.
# Ấẽ păểcÁ;!ặq28b
# .fí(nntếnưĩOs!""ê/1”%? ệâ%Spa" cũếyếáạ”ừE.ặể vỗ 5uố,mạ2ắOốăể,i93ạIy;:ềyỳr. G5ãp Văi,fSõáQôOVôếiũgGẤK,tặ
# lẳóp5B3t(tóạ tìJqỹõọhÔcdOở
# ở oẫynhạtó"ạẵguẩá:ẵtmấn, Tỉ…vNÁ,5ạ6ư.o!8,tềc"ãpêá-// ờt!uằOfr ia ệ0đủthằ,y4.Âữĩbựaở, GKị vẤn"k–Otycềm6ccàIáợểcdũ,Qễ:cẵỷềú/ỗoẽ "ờồn5VA BCNỳíểơẵô%Ju”….ãĐếuAệại(uồnc

# %% [markdown]
#  ## Other remarks:
#  - The network learn the structure of characters in the original text. If we give it a sentence with new character, it will fail :D
#  -

# %% [markdown]
# ## Questions:
# - What happens if we choose the seed_sentence that has no sense
#   - as a sentence, e.g., 'I you me him hello'
#   - as words, for example 'I dnoot uredsbadt waht you siad'
#   - in different language, 'je'n comprends pas', etc?
# - choose to guess the next two characters at the same time, instead of one character
# - word-based guessing instead of character-based guessing like above
# -

# %%
print('Build model...')
model = Sequential()
model.add(LSTM(2, input_shape=(maxlen, 3), return_sequences = True, name = "LSTM"))
model.add(Dense(len(chars), activation='softmax', name = 'Dense'))
# Out:
# Build model...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM (LSTM)                  (None, 40, 2)             48
# _________________________________________________________________
# dense_11 (Dense)             (None, 40, 147)           441
# =================================================================
# Total params: 489
# Trainable params: 489
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
model = Sequential()
model.add(LSTM(5, input_shape = (10, 20), return_sequences = True))
model.add(TimeDistributed(Dense(2)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 10, 5)             520
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 10, 2)             12
# =================================================================
# Total params: 532
# Trainable params: 532
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(LSTM(5, input_shape = (10, 20), return_sequences = True))
model.add((Dense(1)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 10, 5)             520
# _________________________________________________________________
# dense_4 (Dense)              (None, 10, 1)             6
# =================================================================
# Total params: 526
# Trainable params: 526
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
hidden_neurons = 10
time_steps = 75
input_dima = 3
train_set = np.random.randn(100,time_steps, input_dim )
model = Sequential()  
model.add(LSTM(units = hidden_neurons, input_shape= (time_steps,10)))  
model.add(keras.layers.RepeatVector(10))
model.add(LSTM(units = hidden_neurons, return_sequences = True))  
model.add(TimeDistributed(Dense(units = 1)))
model.add(Activation('linear'))   
model.compile(loss = 'mean_squared_error', optimizer = 'rmsprop', metrics = ['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-a5db76425cbb> in <module>()
#      13 model.add(LSTM(units = hidden_neurons, return_sequences = True))
#      14 model.add(TimeDistributed(Dense(units = 1)))
# ---> 15 model.add(Activation('linear'))
#      16 model.compile(loss = 'mean_squared_error', optimizer = 'rmsprop', metrics = ['accuracy'])
#
# NameError: name 'Activation' is not defined

# %%
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
data_dim = 2
X_train_pass = np.random.randn(3281, data_dim)
y_train_pass = np.random.randn(3181,1)

timesteps = 1

train_pass = np.reshape(X_train_pass, (X_train_pass.shape[0], 1, X_train_pass.shape[1]))
#test_pass = np.reshape(X_test_pass, (X_test_pass.shape[0], 1, X_test_pass.shape[1]))
y_train_pass = np.reshape(y_train_pass, (y_train_pass.shape[0], 1, y_train_pass.shape[1]))

model_pass = Sequential()
model_pass.add(LSTM(units=64,  return_sequences=True, 
                input_shape=(timesteps, data_dim)))
model_pass.add(Dense(2, activation='sigmoid'))
model_pass.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
model_pass.summary()
model_pass.fit(train_pass, y_train_pass,batch_size=1, epochs = 1, verbose = 1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_11 (LSTM)               (None, 1, 64)             17152
# _________________________________________________________________
# dense_9 (Dense)              (None, 1, 2)              130
# =================================================================
# Total params: 17,282
# Trainable params: 17,282
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-c952af641275> in <module>()
#      21 model_pass.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
#      22 model_pass.summary()
# ---> 23 model_pass.fit(train_pass, y_train_pass,batch_size=1, epochs = 1, verbose = 1)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     787                 feed_output_shapes,
#     788                 check_batch_axis=False,  # Don't enforce the batch size.
# --> 789                 exception_prefix='target')
#     790
#     791             # Generate sample-wise weight values given the `sample_weight` and
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking target: expected dense_9 to have shape (1, 2) but got array with shape (1, 1)

# %%
from keras.layers import Flatten
def model():
    model = Sequential()
    model.add(Dense(128, input_shape = (LSTM_WINDOW_SIZE,1)))
    model.add(LSTM(units=5,
                   return_sequences=True))
    model.add(Flatten())
  
    model.add(Dense(1, activation = 'linear'))

    model.add(Dense(1))
    return model
LSTM_WINDOW_SIZE = 5
model3 = model()
model3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 5, 128)            256
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 5, 5)              2680
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 26
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 2,964
# Trainable params: 2,964
# Non-trainable params: 0
# _________________________________________________________________

# %%
def model2():
    X = keras.layers.Input(shape=(LSTM_WINDOW_SIZE,1))
     X = Dense(128)(X)
    X = LSTM(units = 5, return_sequences = True)(X)
# Out:
#   File "<ipython-input-58-416b103f88d1>", line 3
#     X = Dense(128)(X)
#     ^
# IndentationError: unexpected indent

# %%
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 5, 128)            256
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 5, 5)              2680
# _________________________________________________________________
# dense_29 (Dense)             (None, 5, 1)              6
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5)                 0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 2,948
# Trainable params: 2,948
# Non-trainable params: 0
# _________________________________________________________________
